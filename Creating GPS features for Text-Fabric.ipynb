# %% [markdown]
# # Geomapping Biblical locations

# %%
import os
import csv, re, collections

# %%
from tf.fabric import Fabric
from tf.extra.bhsa import Bhsa
BHSA = f'etcbc/bhsa/tf/c'
TF = Fabric(modules = BHSA)
# Out:
# This is Text-Fabric 5.5.23
# Api reference : https://dans-labs.github.io/text-fabric/Api/General/
# Tutorial      : https://github.com/Dans-labs/text-fabric/blob/master/docs/tutorial.ipynb
# Example data  : https://github.com/Dans-labs/text-fabric-data
#
# 114 features found and 0 ignored

# %%
api = TF.load('''
    lex gloss nametype sp
''')
api.makeAvailableIn(globals())
# Out:
#   0.00s loading features ...
#    |     0.15s B lex                  from C:/Users/Ejer/text-fabric-data/etcbc/bhsa/tf/c
#    |     0.01s B gloss                from C:/Users/Ejer/text-fabric-data/etcbc/bhsa/tf/c
#    |     0.03s B nametype             from C:/Users/Ejer/text-fabric-data/etcbc/bhsa/tf/c
#    |     0.15s B sp                   from C:/Users/Ejer/text-fabric-data/etcbc/bhsa/tf/c
#   5.43s All features loaded/computed - for details use loadLog()

# %% [markdown]
# ## Production

# %% [markdown]
# #### Lexemes marked for topos in the ETCBC database:

# %%
topo_dict = {}

for n in F.otype.s('lex'):
    if F.nametype.v(n) == 'topo':
        topo_dict[n] = F.gloss.v(n)

len(topo_dict)
# Out:
# 841

# %%
topo_dict
# Out:
# {1437699: 'Eden',
#  1437713: 'Pishon',
#  1437716: 'Havilah',
#  1437722: 'Gihon',
#  1437723: 'Cush',
#  1437724: 'Tigris',
#  1437727: 'Asshur',
#  1437728: 'Euphrates',
#  1437866: 'Nod',
#  1437869: 'Enoch',
#  1437994: 'Ararat',
#  1438052: 'Magog',
#  1438060: 'Togarmah',
#  1438061: 'Elishah',
#  1438062: 'Tarshish',
#  1438068: 'Egypt',
#  1438075: 'Sheba',
#  1438076: 'Dedan',
#  1438080: 'Babel',
#  1438081: 'Erech',
#  1438082: 'Akkad',
#  1438083: 'Calneh',
#  1438084: 'Shinar',
#  1438085: 'Nineveh',
#  1438086: 'Rehoboth Ir',
#  1438087: 'Calah',
#  1438088: 'Resen',
#  1438097: 'Sidon',
#  1438111: 'Gerar',
#  1438112: 'Gaza',
#  1438113: 'Sodom',
#  1438114: 'Gomorrah',
#  1438115: 'Admah',
#  1438116: 'Zeboiim',
#  1438117: 'Lasha',
#  1438122: 'Aram',
#  1438124: 'Hul',
#  1438132: 'Sheleph',
#  1438133: 'Hazarmaveth',
#  1438140: '<land of gold>',
#  1438143: 'Mesha',
#  1438144: 'Sephar',
#  1438172: 'Ur',
#  1438180: '<town>',
#  1438185: 'Shechem',
#  1438187: 'Moreh',
#  1438189: 'Bethel',
#  1438191: 'Ai',
#  1438227: 'Jordan',
#  1438229: 'Zoar',
#  1438234: 'Mamre',
#  1438235: 'Hebron',
#  1438239: 'Ellasar',
#  1438242: 'Goyim',
#  1438248: 'Bela',
#  1438251: 'Siddim',
#  1438255: 'Ashteroth Karnaim',
#  1438257: 'Ham',
#  1438260: 'Kiriathaim',
#  1438262: 'Seir',
#  1438263: 'El Paran',
#  1438265: 'En Mishpat',
#  1438266: 'Kadesh',
#  1438268: 'Hazazon Tamar',
#  1438286: 'Hobah',
#  1438287: 'Damascus',
#  1438289: 'Shaveh',
#  1438291: 'Salem',
#  1438360: 'Shur',
#  1438369: 'Beer Lahai Roi',
#  1438370: 'Bered',
#  1438509: 'Sheba',
#  1438517: 'Paran',
#  1438531: 'Moriah',
#  1438562: 'Kiriath Arba',
#  1438570: 'Machpelah',
#  1438581: 'Mesopotamia',
#  1438645: 'Dumah',
#  1438648: 'Tema',
#  1438675: 'Edom',
#  1438696: 'Esek',
#  1438698: 'Sitnah',
#  1438699: 'Rehoboth',
#  1438705: 'Shibah',
#  1438763: 'Luz',
#  1438856: 'Gilead',
#  1438885: 'Galeed',
#  1438886: 'Mizpah',
#  1438892: 'Mahanaim',
#  1438904: 'Jabbok',
#  1438909: 'Peniel',
#  1438911: '<locality>',
#  1438923: 'Succoth',
#  1438968: 'Bethlehem',
#  1438970: 'Migdal Eder',
#  1438979: 'Teman',
#  1439016: 'Dinhabah',
#  1439018: 'Bozrah',
#  1439023: 'Avith',
#  1439025: 'Masrekah',
#  1439030: 'Pau',
#  1439034: 'Alvah',
#  1439048: 'Dothan',
#  1439081: 'Kezib',
#  1439085: 'Timnah',
#  1439089: 'Enaim',
#  1439126: 'Nile',
#  1439164: '<Heliopolis>',
#  1439217: 'Goshen',
#  1439277: 'Rameses',
#  1439321: 'Shiloh',
#  1439378: 'Abel Mizraim',
#  1439389: 'Pithom',
#  1439417: 'Horeb',
#  1439583: 'Etham',
#  1439587: 'Pi Hahiroth',
#  1439588: 'Migdol',
#  1439589: 'Baal Zephon',
#  1439627: 'Philistia',
#  1439639: 'Marah',
#  1439644: 'Elim',
#  1439646: 'Sin',
#  1439647: 'Sinai',
#  1439674: 'Rephidim',
#  1439678: 'Massah',
#  1439679: 'Meribah',
#  1440377: 'Taberah',
#  1440398: 'Kibroth Hattaavah',
#  1440399: 'Hazeroth',
#  1440430: 'Zin',
#  1440431: 'Rehob',
#  1440432: 'Hamath',
#  1440437: 'Zoan',
#  1440438: '<valley of grapes>',
#  1440449: 'Hormah',
#  1440476: 'Mount Hor',
#  1440477: 'Arad',
#  1440478: 'Atharim',
#  1440481: 'Oboth',
#  1440482: 'Iye Abarim',
#  1440483: 'Zered',
#  1440484: 'Arnon',
#  1440485: 'Waheb',
#  1440486: 'Suphah',
#  1440488: 'Ar',
#  1440489: 'Beer',
#  1440490: 'Mattanah',
#  1440491: 'Nahaliel',
#  1440492: 'Bamoth',
#  1440494: 'Pisgah',
#  1440495: 'Jeshimon',
#  1440497: 'Jahzah',
#  1440498: 'Heshbon',
#  1440506: 'Dibon',
#  1440507: 'Nophah',
#  1440508: 'Medeba',
#  1440509: 'Jazer',
#  1440511: 'Bashan',
#  1440513: 'Edrei',
#  1440516: 'Jericho',
#  1440522: 'Pethor',
#  1440532: 'Kiriath Huzoth',
#  1440533: 'Bamoth Baal',
#  1440546: 'Peor',
#  1440563: 'Shittim',
#  1440656: 'Abarim',
#  1440673: 'Ataroth',
#  1440674: 'Nimrah',
#  1440675: 'Elealeh',
#  1440676: 'Sebam',
#  1440677: '<mountain>',
#  1440678: 'Beon',
#  1440679: 'Kadesh Barnea',
#  1440685: 'Aroer',
#  1440686: 'Atroth Shophan',
#  1440687: 'Jogbehah',
#  1440688: 'Beth Nimrah',
#  1440689: 'Beth Haran',
#  1440690: 'Baal Meon',
#  1440691: 'Sibmah',
#  1440695: 'Kenath',
#  1440696: 'Nobah',
#  1440697: 'Pi Hahiroth',
#  1440698: 'Dophkah',
#  1440699: 'Alush',
#  1440700: 'Rithmah',
#  1440701: 'Rimmon Perez',
#  1440702: 'Libnah',
#  1440703: 'Rissah',
#  1440704: 'Kehelathah',
#  1440705: 'Shepher',
#  1440706: 'Haradah',
#  1440707: 'Makheloth',
#  1440708: 'Tahath',
#  1440709: 'Terah',
#  1440710: 'Mithcah',
#  1440711: 'Hashmonah',
#  1440712: 'Moseroth',
#  1440713: 'Bene Jaakan',
#  1440714: 'Hor Haggidgad',
#  1440715: 'Jotbathah',
#  1440716: 'Abronah',
#  1440717: 'Ezion Geber',
#  1440718: 'Zalmonah',
#  1440719: 'Punon',
#  1440720: 'Iyim',
#  1440721: 'Almon Diblathaim',
#  1440722: 'Beth Jeshimoth',
#  1440723: 'Abel Shittim',
#  1440727: 'Scorpion Pass',
#  1440729: 'Hazar Addar',
#  1440730: 'Azmon',
#  1440732: 'Zedad',
#  1440733: 'Ziphron',
#  1440734: 'Hazar Enan',
#  1440735: 'Shepham',
#  1440736: 'Riblah',
#  1440737: 'Ain',
#  1440739: 'Kinnereth',
#  1440760: 'Suph',
#  1440761: 'Tophel',
#  1440762: 'Laban',
#  1440763: 'Dizahab',
#  1440764: 'Ashtaroth',
#  1440767: 'Lebanon',
#  1440782: 'Elath',
#  1440788: 'Caphtor',
#  1440790: 'Kedemoth',
#  1440793: 'Argob',
#  1440795: 'Hermon',
#  1440797: 'Sirion',
#  1440798: 'Senir',
#  1440800: 'Salecah',
#  1440806: 'Beth Peor',
#  1440815: '<place of refuge>',
#  1440816: 'Ramoth',
#  1440817: 'Golan',
#  1440819: 'Siyon',
#  1440843: 'the wells of the Jaakanites',
#  1440844: 'Moserah',
#  1440845: 'Hor Haggidgad',
#  1440851: 'Gerizim',
#  1440852: 'Ebal',
#  1440854: 'Gilgal',
#  1441089: 'Adam',
#  1441090: 'Zarethan',
#  1441096: 'Beth Aven',
#  1441098: 'Shebarim',
#  1441101: 'Achor',
#  1441105: 'Gibeon',
#  1441113: 'Kephirah',
#  1441114: 'Beeroth',
#  1441115: 'Kiriath Jearim',
#  1441117: 'Jerusalem',
#  1441120: 'Jarmuth',
#  1441122: 'Lachish',
#  1441124: 'Eglon',
#  1441126: 'Beth Horon',
#  1441127: 'Azekah',
#  1441128: 'Makkedah',
#  1441129: 'Aijalon',
#  1441133: 'Gezer',
#  1441134: 'Debir',
#  1441136: 'Hazor',
#  1441137: 'Madon',
#  1441138: 'Shimron',
#  1441139: 'Acshaph',
#  1441141: 'Dor',
#  1441142: 'Merom',
#  1441143: 'Misrephoth Maim',
#  1441144: 'Mizpeh',
#  1441145: 'Baal Gad',
#  1441147: 'Anab',
#  1441148: 'Gath',
#  1441149: 'Ashdod',
#  1441152: 'Geder',
#  1441153: 'Adullam',
#  1441154: 'Tappuah',
#  1441155: 'Hepher',
#  1441156: 'Aphek',
#  1441157: 'Sharon',
#  1441158: 'Shimron Meron',
#  1441159: 'Taanach',
#  1441160: 'Megiddo',
#  1441161: 'Kedesh',
#  1441162: 'Jokneam',
#  1441163: 'Carmel',
#  1441164: 'Tirzah',
#  1441166: 'Shihor',
#  1441167: 'Ekron',
#  1441174: 'Mearah',
#  1441177: 'Geshur',
#  1441179: 'Baal Meon',
#  1441180: 'Mephaath',
#  1441181: 'Zereth Shahar',
#  1441183: 'Rabbah',
#  1441186: 'Betonim',
#  1441187: 'Debir',
#  1441188: 'Beth Haram',
#  1441189: 'Zaphon',
#  1441191: 'Hezron',
#  1441192: '<town>',
#  1441193: 'Karka',
#  1441194: 'Beth Hoglah',
#  1441195: 'Beth Arabah',
#  1441197: 'the Pass of Adummim',
#  1441198: 'En Shemesh',
#  1441199: 'En Rogel',
#  1441200: 'the Valley of Ben Hinnom',
#  1441202: '<valley>',
#  1441204: 'Nephtoah',
#  1441205: 'Ephron',
#  1441206: 'Baalah',
#  1441207: 'Jearim',
#  1441208: 'Kesalon',
#  1441209: 'Beth Shemesh',
#  1441210: 'Shikkeron',
#  1441211: 'Jabneel',
#  1441212: 'Kiriath Sepher',
#  1441218: 'Kabzeel',
#  1441219: 'Eder',
#  1441220: 'Jagur',
#  1441221: 'Kinah',
#  1441222: 'Dimonah',
#  1441223: 'Adadah',
#  1441224: 'Ithnan',
#  1441225: 'Ziph',
#  1441226: 'Telem',
#  1441227: 'Bealoth',
#  1441228: 'Hazor Hadattah',
#  1441229: 'Kerioth',
#  1441230: 'Amam',
#  1441231: 'Shema',
#  1441232: 'Moladah',
#  1441233: 'Hazar Gaddah',
#  1441234: 'Heshmon',
#  1441235: 'Beth Pelet',
#  1441236: 'Hazar Shual',
#  1441237: 'Biziothiah',
#  1441238: 'Ezem',
#  1441239: 'Eltolad',
#  1441240: 'Kesil',
#  1441241: 'Ziklag',
#  1441242: 'Madmannah',
#  1441243: 'Sansannah',
#  1441244: 'Lebaoth',
#  1441245: 'Shilhim',
#  1441246: 'En Rimmon',
#  1441247: 'Eshtaol',
#  1441248: 'Zorah',
#  1441249: 'Ashnah',
#  1441250: 'Zanoah',
#  1441251: 'En Gannim',
#  1441252: 'Enam',
#  1441253: 'Socoh',
#  1441254: 'Shaaraim',
#  1441255: 'Adithaim',
#  1441256: 'Gederah',
#  1441257: 'Gederothaim',
#  1441258: 'Zenan',
#  1441259: 'Hadashah',
#  1441260: 'Migdal Gad',
#  1441261: 'Dilean',
#  1441262: 'Joktheel',
#  1441263: 'Bozkath',
#  1441264: 'Cabbon',
#  1441265: 'Lahmas',
#  1441266: 'Kitlish',
#  1441267: 'Gederoth',
#  1441268: 'Beth Dagon',
#  1441269: 'Naamah',
#  1441270: 'Ether',
#  1441271: 'Ashan',
#  1441272: 'Iphtah',
#  1441273: 'Nezib',
#  1441274: 'Keilah',
#  1441275: 'Aczib',
#  1441276: 'Mareshah',
#  1441277: 'Shamir',
#  1441278: 'Jattir',
#  1441279: 'Dannah',
#  1441280: 'Kiriath Sannah',
#  1441281: 'Eshtemoa',
#  1441282: 'Anim',
#  1441283: 'Holon',
#  1441284: 'Giloh',
#  1441285: 'Arab',
#  1441286: 'Rumah',
#  1441287: 'Eshan',
#  1441288: 'Janim',
#  1441289: 'Beth Tappuah',
#  1441290: 'Aphekah',
#  1441291: 'Humtah',
#  1441292: 'Zior',
#  1441293: 'Maon',
#  1441294: 'Juttah',
#  1441295: '<town>',
#  1441296: 'Jokdeam',
#  1441297: 'Kain',
#  1441298: 'Gibeah',
#  1441299: 'Halhul',
#  1441300: 'Beth Zur',
#  1441301: 'Gedor',
#  1441302: 'Maarath',
#  1441303: 'Beth Anoth',
#  1441304: 'Eltekon',
#  1441305: 'Kiriath Baal',
#  1441306: 'Middin',
#  1441307: 'Secacah',
#  1441308: 'Nibshan',
#  1441309: 'City of Salt',
#  1441310: 'En Gedi',
#  1441314: 'Ataroth Addar',
#  1441315: 'Micmethath',
#  1441316: 'Taanath Shiloh',
#  1441317: 'Janoah',
#  1441318: '<locality>',
#  1441319: 'Kanah',
#  1441322: 'En Tappuah',
#  1441323: 'Beth Shan',
#  1441324: 'Ibleam',
#  1441325: 'Dor',
#  1441326: 'Endor',
#  1441329: 'Shiloh',
#  1441330: 'Geliloth',
#  1441331: 'Emek Keziz',
#  1441332: '<mountain>',
#  1441333: 'Parah',
#  1441334: 'Ophrah',
#  1441336: 'Ammoni',
#  1441337: 'Ophni',
#  1441338: 'Geba',
#  1441339: 'Ramah',
#  1441340: 'Mozah',
#  1441341: 'Rekem',
#  1441342: 'Irpeel',
#  1441343: 'Taralah',
#  1441344: 'Zela',
#  1441345: 'Eleph',
#  1441346: 'Gibeath',
#  1441347: 'Kiriath',
#  1441348: 'Balah',
#  1441349: 'Bethuel',
#  1441350: 'Beth Marcaboth',
#  1441351: 'Hazar Susah',
#  1441352: 'Beth Lebaoth',
#  1441353: 'Sharuhen',
#  1441354: 'Rimmon',
#  1441355: 'Baalath Beer',
#  1441356: 'Sarid',
#  1441357: 'Maralah',
#  1441358: 'Dabbesheth',
#  1441359: 'Kisloth Tabor',
#  1441360: 'Daberath',
#  1441361: 'Japhia',
#  1441363: 'Neah',
#  1441364: 'Hannathon',
#  1441365: 'Iphtah El',
#  1441366: 'Kattath',
#  1441367: 'Nahalal',
#  1441368: 'Idalah',
#  1441369: 'Kesulloth',
#  1441370: 'Shunem',
#  1441371: 'Hapharaim',
#  1441372: 'Shion',
#  1441373: 'Anaharath',
#  1441374: 'Rabbith',
#  1441375: 'Kishion',
#  1441376: 'Ebez',
#  1441377: 'Remeth',
#  1441378: 'En Haddah',
#  1441379: 'Beth Pazzez',
#  1441380: 'Tabor',
#  1441381: 'Shahazumah',
#  1441382: 'Helkath',
#  1441383: 'Hali',
#  1441384: 'Beten',
#  1441385: 'Allammelech',
#  1441386: 'Amad',
#  1441387: 'Mishal',
#  1441388: 'Shihor Libnath',
#  1441389: 'Beth Emek',
#  1441390: 'Neiel',
#  1441391: 'Cabul',
#  1441392: 'Abdon',
#  1441393: 'Hammon',
#  1441394: 'Tyrus',
#  1441395: 'Hosah',
#  1441396: 'Ummah',
#  1441397: 'Heleph',
#  1441398: 'Zaanannim',
#  1441399: 'Adami-nekeb',
#  1441400: 'Lakkum',
#  1441401: 'Aznoth Tabor',
#  1441402: 'Hukkok',
#  1441403: 'Ziddim',
#  1441404: 'Zer',
#  1441405: 'Hammath',
#  1441406: 'Rakkath',
#  1441407: 'Adamah',
#  1441408: 'En Hazor',
#  1441409: 'Iron',
#  1441410: 'Migdal El',
#  1441411: 'Horem',
#  1441412: 'Beth Anath',
#  1441413: 'Ir Shemesh',
#  1441414: 'Shaalabbin',
#  1441415: 'Ithlah',
#  1441416: 'Elon',
#  1441417: 'Eltekeh',
#  1441418: 'Gibbethon',
#  1441419: 'Baalath',
#  1441420: 'Jehud',
#  1441421: 'Bene Berak',
#  1441422: 'Gath Rimmon',
#  1441423: 'Jarkon',
#  1441424: 'Rakkon',
#  1441425: 'Joppa',
#  1441426: 'Leshem',
#  1441427: 'Timnath Serah',
#  1441428: 'Galilee',
#  1441431: '<town>',
#  1441432: 'Almon',
#  1441433: 'Kibzaim',
#  1441434: 'Be Eshtarah',
#  1441435: 'Abdon',
#  1441436: 'Hammoth Dor',
#  1441437: 'Kartan',
#  1441438: 'Kartah',
#  1441439: 'Dimnah',
#  1441448: 'Gaash',
#  1441449: 'Bezek',
#  1441452: 'Zephath',
#  1441453: 'Ashkelon',
#  1441454: 'Kitron',
#  1441455: 'Nahalol',
#  1441456: 'Acco',
#  1441457: 'Ahlab',
#  1441458: 'Helbah',
#  1441459: 'Aphek',
#  1441461: 'Mount Heres',
#  1441462: 'Shaalbim',
#  1441463: 'Sela',
#  1441464: 'Bokim',
#  1441466: 'Timnath Heres',
#  1441471: 'Baal Hermon',
#  1441487: 'Seirah',
#  1441492: 'Harosheth Haggoyim',
#  1441498: 'Kishon',
#  1441530: 'Meroz',
#  1441556: 'the spring of Harod',
#  1441564: 'Beth Shittah',
#  1441565: 'Zererah',
#  1441566: 'Abel Meholah',
#  1441567: 'Tabbath',
#  1441568: 'Beth Barah',
#  1441575: 'Karkor',
#  1441576: 'the Pass of Heres',
#  1441592: 'Tormah',
#  1441594: 'Arumah',
#  1441597: 'Zalmon',
#  1441601: 'Thebez',
#  1441605: 'Kamon',
#  1441607: 'Tob',
#  1441608: 'Aroer',
#  1441609: 'Minnith',
#  1441610: 'Abel Keramim',
#  1441618: 'Pirathon',
#  1441624: 'Mahaneh Dan',
#  1441639: 'Etam',
#  1441640: 'Lehi',
#  1441645: 'Sorek',
#  1441662: '<locality>',
#  1441667: 'Beth Rehob',
#  1441672: 'Jebus',
#  1441680: 'Baal Tamar',
#  1441684: 'Gidom',
#  1441686: 'Jabesh',
#  1441687: 'Lebonah',
#  1441730: 'Ebenezer',
#  1441747: 'Beth Car',
#  1441748: 'Shen',
#  1441759: 'Shalisha',
#  1441760: 'Shaalim',
#  1441768: 'Zelzah',
#  1441779: 'Micmash',
#  1441782: 'Shual',
#  1441783: 'Zeboim',
#  1441792: 'Migron',
#  1441795: 'Bozez',
#  1441796: 'Seneh',
#  1441806: 'Zobah',
#  1441815: 'Telaim',
#  1441827: 'Ephes Dammim',
#  1441858: 'Naioth',
#  1441860: 'Secu',
#  1441868: 'Nob',
#  1441882: 'Hereth',
#  1441885: 'Horesh',
#  1441887: 'Hakilah',
#  1441905: 'Gallim',
#  1441920: 'Gilboa',
#  1441924: 'Besor',
#  1441929: 'Siphmoth',
#  1441930: 'Racal',
#  1441931: 'Bor Ashan',
#  1441932: 'Athach',
#  1441944: 'Helkath Hazzurim',
#  1441948: 'Ammah',
#  1441949: 'Giah',
#  1441962: 'Bahurim',
#  1441964: 'Sirah',
#  1441973: 'Gittaim',
#  1441977: 'Zion',
#  1441987: 'Baal Perazim',
#  1441991: 'Baalah of Judah',
#  1441999: 'Perez Uzzah',
#  1442014: 'Tebah',
#  1442015: 'Berothai',
#  1442018: 'the Valley of Salt',
#  1442027: 'Lo Debar',
#  1442032: 'Maacah',
#  1442034: 'Helam',
#  1442056: 'Baal Hazor',
#  1442058: 'Tekoa',
#  1442072: 'Kidron',
#  1442091: 'Rogelim',
#  1442107: 'Abel',
#  1442123: 'Gob',
#  1442202: 'Tahtim Hodshi',
#  1442212: 'Zoheleth',
#  1442227: 'Makaz',
#  1442228: 'Bethhanan',
#  1442230: 'Arubboth',
#  1442233: 'Jokmeam',
#  1442244: 'Tiphsah',
#  1442318: 'Tadmor',
#  1442327: 'Arabia',
#  1442346: 'Zeredah',
#  1442362: 'Samaria',
#  1442378: 'Ijon',
#  1442379: 'Abel-beth-maacah',
#  1442396: 'Kerith',
#  1442397: 'Zarephath',
#  1442453: 'Kir Hareseth',
#  1442464: 'Baal Shalishah',
#  1442467: 'Amana',
#  1442468: 'Pharpar',
#  1442471: 'Ophel',
#  1442486: 'Zair',
#  1442493: 'Beth Haggan',
#  1442494: 'the way up to Gur',
#  1442499: 'Beth Eked of the Shepherds',
#  1442500: 'Beth Eked',
#  1442509: 'Sur',
#  1442518: 'Silla',
#  1442532: 'Gath Hepher',
#  1442549: 'Janoah',
#  1442555: 'Kir',
#  1442556: 'Damascus',
#  1442562: 'Halah',
#  1442563: 'Habor',
#  1442564: 'Gozan',
#  1442567: 'Cuthah',
#  1442568: 'Avva',
#  1442569: 'Sepharvaim',
#  1442595: 'Arpad',
#  1442596: 'Hena',
#  1442597: 'Ivvah',
#  1442607: 'Rezeph',
#  1442608: 'Eden',
#  1442609: 'Telassar',
#  1442615: 'Egypt',
#  1442641: 'Jotbah',
#  1442655: 'Topheth',
#  1442806: 'Shiloah',
#  1442836: 'Carchemish',
#  1442837: 'Calno',
#  1442851: 'Aiath',
#  1442853: 'Laishah',
#  1442854: 'Madmenah',
#  1442855: 'Gebim',
#  1442870: 'Upper Egypt',
#  1442916: 'Kir in Moab',
#  1442917: 'Jahaz',
#  1442919: 'Eglath Shelishiyah',
#  1442920: 'Luhith',
#  1442921: 'Horonaim',
#  1442922: 'Nimrim',
#  1442925: 'Eglaim',
#  1442927: 'Beer Elim',
#  1442928: 'Dimon',
#  1442940: 'Kir Hareseth',
#  1442986: 'Memphis',
#  1443096: 'Perazim',
#  1443107: '<part of Jerusalem>',
#  1443126: 'Hanes',
#  1443130: '<Egypt>',
#  1443312: 'Aswan',
#  1443388: 'Ephah',
#  1443423: 'Tahpanhes',
#  1443459: 'Beth Hakkerem',
#  1443496: 'Uphaz',
#  1443583: 'Uz',
#  1443584: 'Buz',
#  1443586: 'Sheshach',
#  1443618: 'Hananel',
#  1443619: 'Goah',
#  1443689: 'Thebes',
#  1443692: 'Madmen',
#  1443696: 'Beth Diblathaim',
#  1443697: 'Beth Gamul',
#  1443698: 'Beth Meon',
#  1443711: 'Merathaim',
#  1443712: 'Pekod',
#  1443719: 'Minni',
#  1443728: 'Kebar',
#  1443741: 'Tel Abib',
#  1443755: 'Riblah',
#  1443891: 'Arvad',
#  1443893: '<mountain>',
#  1443897: 'Helech',
#  1443907: 'Helbon',
#  1443908: 'Zahar',
#  1443913: 'Canneh',
#  1443914: 'Kilmad',
#  1443934: 'from Migdol to Aswan',
#  1443937: 'Libya',
#  1443938: 'Sin',
#  1443939: '<town>',
#  1443940: 'Bubastis',
#  1443970: 'Hamonah',
#  1444003: 'En Eglaim',
#  1444007: 'Hethlon',
#  1444008: 'Berothah',
#  1444009: 'Sibraim',
#  1444010: 'Hauran',
#  1444011: 'Hazar Enan',
#  1444012: 'Tamar',
#  1444047: 'Memphis',
#  1444058: 'Beth Arbel',
#  1444091: 'the Valley of Aven',
#  1444092: 'Beth Eden',
#  1444101: 'Harmon',
#  1444115: 'Karnaim',
#  1444132: 'Sepharad',
#  1444143: 'Aphrah',
#  1444144: 'Shaphir',
#  1444145: 'Zaanan',
#  1444146: 'Beth Ezel',
#  1444148: 'Maroth',
#  1444150: 'Moresheth Gath',
#  1444187: 'Thebes',
#  1444263: 'Hadrach',
#  1444280: 'Azel',
#  1444490: 'Gebal',
#  1444566: 'Jaar',
#  1445012: 'Bath Rabbim',
#  1445018: 'Baal Hamon',
#  1445103: 'India',
#  1445104: 'Susa',
#  1445253: 'Babylon',
#  1445310: 'Judaea',
#  1445416: 'Dura',
#  1445589: 'Jerusalem',
#  1445629: 'Media',
#  1445630: 'Persia',
#  1445743: 'Ulai',
#  1445787: 'Gibbar',
#  1445788: 'Netophah',
#  1445789: 'Micmash',
#  1445792: 'Lod',
#  1445793: 'Hadid',
#  1445794: 'Ono',
#  1445841: 'Tel Melah',
#  1445842: 'Tel Harsha',
#  1445843: 'Kerub',
#  1445844: 'Addon',
#  1445882: 'Samaria',
#  1445942: 'Ecbatana',
#  1446022: 'Ahava',
#  1446026: 'Casiphia',
#  1446083: 'the Jackal Well',
#  1446086: 'the Hundred',
#  1446121: 'Kephirim',
#  1446132: 'Azmaveth',
#  1446136: 'Addon',
#  1446187: 'Jekabzeel',
#  1446188: 'Jeshua',
#  1446189: 'Meconah',
#  1446190: 'Aiah',
#  1446191: 'Ananiah',
#  1446192: 'Neballat',
#  1446210: 'Beth Gilgal',
#  1446227: 'Pai',
#  1446266: 'Jorkeam',
#  1446282: 'Beth Gader',
#  1446289: 'Atroth Beth Joab',
#  1446292: 'Jabez',
#  1446339: 'Ir Nahash',
#  1446340: 'Recah',
#  1446367: 'Lecah',
#  1446371: 'Cozeba',
#  1446374: 'Netaim',
#  1446376: 'Bilhah',
#  1446377: 'Tolad',
#  1446378: 'Beth Marcaboth',
#  1446379: 'Hazar Susim',
#  1446380: 'Beth Biri',
#  1446381: 'Token',
#  1446382: 'Baalath',
#  1446414: 'Hara',
#  1446430: 'Hilez',
#  1446431: 'Alemeth',
#  1446432: 'Aner',
#  1446433: 'Bileam',
#  1446434: 'Anem',
#  1446435: 'Mashal',
#  1446436: 'Hukok',
#  1446437: 'Rimmono',
#  1446466: 'Uzzen Sheerah',
#  1446471: 'Naaran',
#  1446508: 'Manahath',
#  1446649: 'Damascus',
#  1446650: 'Tibhath',
#  1446651: 'Cun',
#  1446654: 'Aram Maacah',
#  1446712: 'Shalleketh',
#  1446733: 'Kue',
#  1446739: 'Parvaim',
#  1446744: 'Hamath Zobah',
#  1446749: 'Adoraim',
#  1446753: 'Jeshanah',
#  1446754: 'Ephron',
#  1446757: 'Zephathah',
#  1446759: 'Abel Maim',
#  1446769: 'Ziz',
#  1446770: 'Jeruel',
#  1446779: 'Jabneh',
#  1446780: 'Gur Baal',
#  1446783: 'Gimzo'}

# %%
collections.Counter(topo_dict.values()).most_common()
# Out:
# [('<town>', 5),
#  ('Damascus', 3),
#  ('<locality>', 3),
#  ('<mountain>', 3),
#  ('Eden', 2),
#  ('Egypt', 2),
#  ('Sheba', 2),
#  ('Shiloh', 2),
#  ('Pi Hahiroth', 2),
#  ('Sin', 2),
#  ('Aroer', 2),
#  ('Baal Meon', 2),
#  ('Hor Haggidgad', 2),
#  ('Hazar Enan', 2),
#  ('Riblah', 2),
#  ('Jerusalem', 2),
#  ('Debir', 2),
#  ('Dor', 2),
#  ('Aphek', 2),
#  ('Ephron', 2),
#  ('Janoah', 2),
#  ('Beth Marcaboth', 2),
#  ('Abdon', 2),
#  ('Baalath', 2),
#  ('Micmash', 2),
#  ('Samaria', 2),
#  ('Kir Hareseth', 2),
#  ('Memphis', 2),
#  ('Thebes', 2),
#  ('Addon', 2),
#  ('Pishon', 1),
#  ('Havilah', 1),
#  ('Gihon', 1),
#  ('Cush', 1),
#  ('Tigris', 1),
#  ('Asshur', 1),
#  ('Euphrates', 1),
#  ('Nod', 1),
#  ('Enoch', 1),
#  ('Ararat', 1),
#  ('Magog', 1),
#  ('Togarmah', 1),
#  ('Elishah', 1),
#  ('Tarshish', 1),
#  ('Dedan', 1),
#  ('Babel', 1),
#  ('Erech', 1),
#  ('Akkad', 1),
#  ('Calneh', 1),
#  ('Shinar', 1),
#  ('Nineveh', 1),
#  ('Rehoboth Ir', 1),
#  ('Calah', 1),
#  ('Resen', 1),
#  ('Sidon', 1),
#  ('Gerar', 1),
#  ('Gaza', 1),
#  ('Sodom', 1),
#  ('Gomorrah', 1),
#  ('Admah', 1),
#  ('Zeboiim', 1),
#  ('Lasha', 1),
#  ('Aram', 1),
#  ('Hul', 1),
#  ('Sheleph', 1),
#  ('Hazarmaveth', 1),
#  ('<land of gold>', 1),
#  ('Mesha', 1),
#  ('Sephar', 1),
#  ('Ur', 1),
#  ('Shechem', 1),
#  ('Moreh', 1),
#  ('Bethel', 1),
#  ('Ai', 1),
#  ('Jordan', 1),
#  ('Zoar', 1),
#  ('Mamre', 1),
#  ('Hebron', 1),
#  ('Ellasar', 1),
#  ('Goyim', 1),
#  ('Bela', 1),
#  ('Siddim', 1),
#  ('Ashteroth Karnaim', 1),
#  ('Ham', 1),
#  ('Kiriathaim', 1),
#  ('Seir', 1),
#  ('El Paran', 1),
#  ('En Mishpat', 1),
#  ('Kadesh', 1),
#  ('Hazazon Tamar', 1),
#  ('Hobah', 1),
#  ('Shaveh', 1),
#  ('Salem', 1),
#  ('Shur', 1),
#  ('Beer Lahai Roi', 1),
#  ('Bered', 1),
#  ('Paran', 1),
#  ('Moriah', 1),
#  ('Kiriath Arba', 1),
#  ('Machpelah', 1),
#  ('Mesopotamia', 1),
#  ('Dumah', 1),
#  ('Tema', 1),
#  ('Edom', 1),
#  ('Esek', 1),
#  ('Sitnah', 1),
#  ('Rehoboth', 1),
#  ('Shibah', 1),
#  ('Luz', 1),
#  ('Gilead', 1),
#  ('Galeed', 1),
#  ('Mizpah', 1),
#  ('Mahanaim', 1),
#  ('Jabbok', 1),
#  ('Peniel', 1),
#  ('Succoth', 1),
#  ('Bethlehem', 1),
#  ('Migdal Eder', 1),
#  ('Teman', 1),
#  ('Dinhabah', 1),
#  ('Bozrah', 1),
#  ('Avith', 1),
#  ('Masrekah', 1),
#  ('Pau', 1),
#  ('Alvah', 1),
#  ('Dothan', 1),
#  ('Kezib', 1),
#  ('Timnah', 1),
#  ('Enaim', 1),
#  ('Nile', 1),
#  ('<Heliopolis>', 1),
#  ('Goshen', 1),
#  ('Rameses', 1),
#  ('Abel Mizraim', 1),
#  ('Pithom', 1),
#  ('Horeb', 1),
#  ('Etham', 1),
#  ('Migdol', 1),
#  ('Baal Zephon', 1),
#  ('Philistia', 1),
#  ('Marah', 1),
#  ('Elim', 1),
#  ('Sinai', 1),
#  ('Rephidim', 1),
#  ('Massah', 1),
#  ('Meribah', 1),
#  ('Taberah', 1),
#  ('Kibroth Hattaavah', 1),
#  ('Hazeroth', 1),
#  ('Zin', 1),
#  ('Rehob', 1),
#  ('Hamath', 1),
#  ('Zoan', 1),
#  ('<valley of grapes>', 1),
#  ('Hormah', 1),
#  ('Mount Hor', 1),
#  ('Arad', 1),
#  ('Atharim', 1),
#  ('Oboth', 1),
#  ('Iye Abarim', 1),
#  ('Zered', 1),
#  ('Arnon', 1),
#  ('Waheb', 1),
#  ('Suphah', 1),
#  ('Ar', 1),
#  ('Beer', 1),
#  ('Mattanah', 1),
#  ('Nahaliel', 1),
#  ('Bamoth', 1),
#  ('Pisgah', 1),
#  ('Jeshimon', 1),
#  ('Jahzah', 1),
#  ('Heshbon', 1),
#  ('Dibon', 1),
#  ('Nophah', 1),
#  ('Medeba', 1),
#  ('Jazer', 1),
#  ('Bashan', 1),
#  ('Edrei', 1),
#  ('Jericho', 1),
#  ('Pethor', 1),
#  ('Kiriath Huzoth', 1),
#  ('Bamoth Baal', 1),
#  ('Peor', 1),
#  ('Shittim', 1),
#  ('Abarim', 1),
#  ('Ataroth', 1),
#  ('Nimrah', 1),
#  ('Elealeh', 1),
#  ('Sebam', 1),
#  ('Beon', 1),
#  ('Kadesh Barnea', 1),
#  ('Atroth Shophan', 1),
#  ('Jogbehah', 1),
#  ('Beth Nimrah', 1),
#  ('Beth Haran', 1),
#  ('Sibmah', 1),
#  ('Kenath', 1),
#  ('Nobah', 1),
#  ('Dophkah', 1),
#  ('Alush', 1),
#  ('Rithmah', 1),
#  ('Rimmon Perez', 1),
#  ('Libnah', 1),
#  ('Rissah', 1),
#  ('Kehelathah', 1),
#  ('Shepher', 1),
#  ('Haradah', 1),
#  ('Makheloth', 1),
#  ('Tahath', 1),
#  ('Terah', 1),
#  ('Mithcah', 1),
#  ('Hashmonah', 1),
#  ('Moseroth', 1),
#  ('Bene Jaakan', 1),
#  ('Jotbathah', 1),
#  ('Abronah', 1),
#  ('Ezion Geber', 1),
#  ('Zalmonah', 1),
#  ('Punon', 1),
#  ('Iyim', 1),
#  ('Almon Diblathaim', 1),
#  ('Beth Jeshimoth', 1),
#  ('Abel Shittim', 1),
#  ('Scorpion Pass', 1),
#  ('Hazar Addar', 1),
#  ('Azmon', 1),
#  ('Zedad', 1),
#  ('Ziphron', 1),
#  ('Shepham', 1),
#  ('Ain', 1),
#  ('Kinnereth', 1),
#  ('Suph', 1),
#  ('Tophel', 1),
#  ('Laban', 1),
#  ('Dizahab', 1),
#  ('Ashtaroth', 1),
#  ('Lebanon', 1),
#  ('Elath', 1),
#  ('Caphtor', 1),
#  ('Kedemoth', 1),
#  ('Argob', 1),
#  ('Hermon', 1),
#  ('Sirion', 1),
#  ('Senir', 1),
#  ('Salecah', 1),
#  ('Beth Peor', 1),
#  ('<place of refuge>', 1),
#  ('Ramoth', 1),
#  ('Golan', 1),
#  ('Siyon', 1),
#  ('the wells of the Jaakanites', 1),
#  ('Moserah', 1),
#  ('Gerizim', 1),
#  ('Ebal', 1),
#  ('Gilgal', 1),
#  ('Adam', 1),
#  ('Zarethan', 1),
#  ('Beth Aven', 1),
#  ('Shebarim', 1),
#  ('Achor', 1),
#  ('Gibeon', 1),
#  ('Kephirah', 1),
#  ('Beeroth', 1),
#  ('Kiriath Jearim', 1),
#  ('Jarmuth', 1),
#  ('Lachish', 1),
#  ('Eglon', 1),
#  ('Beth Horon', 1),
#  ('Azekah', 1),
#  ('Makkedah', 1),
#  ('Aijalon', 1),
#  ('Gezer', 1),
#  ('Hazor', 1),
#  ('Madon', 1),
#  ('Shimron', 1),
#  ('Acshaph', 1),
#  ('Merom', 1),
#  ('Misrephoth Maim', 1),
#  ('Mizpeh', 1),
#  ('Baal Gad', 1),
#  ('Anab', 1),
#  ('Gath', 1),
#  ('Ashdod', 1),
#  ('Geder', 1),
#  ('Adullam', 1),
#  ('Tappuah', 1),
#  ('Hepher', 1),
#  ('Sharon', 1),
#  ('Shimron Meron', 1),
#  ('Taanach', 1),
#  ('Megiddo', 1),
#  ('Kedesh', 1),
#  ('Jokneam', 1),
#  ('Carmel', 1),
#  ('Tirzah', 1),
#  ('Shihor', 1),
#  ('Ekron', 1),
#  ('Mearah', 1),
#  ('Geshur', 1),
#  ('Mephaath', 1),
#  ('Zereth Shahar', 1),
#  ('Rabbah', 1),
#  ('Betonim', 1),
#  ('Beth Haram', 1),
#  ('Zaphon', 1),
#  ('Hezron', 1),
#  ('Karka', 1),
#  ('Beth Hoglah', 1),
#  ('Beth Arabah', 1),
#  ('the Pass of Adummim', 1),
#  ('En Shemesh', 1),
#  ('En Rogel', 1),
#  ('the Valley of Ben Hinnom', 1),
#  ('<valley>', 1),
#  ('Nephtoah', 1),
#  ('Baalah', 1),
#  ('Jearim', 1),
#  ('Kesalon', 1),
#  ('Beth Shemesh', 1),
#  ('Shikkeron', 1),
#  ('Jabneel', 1),
#  ('Kiriath Sepher', 1),
#  ('Kabzeel', 1),
#  ('Eder', 1),
#  ('Jagur', 1),
#  ('Kinah', 1),
#  ('Dimonah', 1),
#  ('Adadah', 1),
#  ('Ithnan', 1),
#  ('Ziph', 1),
#  ('Telem', 1),
#  ('Bealoth', 1),
#  ('Hazor Hadattah', 1),
#  ('Kerioth', 1),
#  ('Amam', 1),
#  ('Shema', 1),
#  ('Moladah', 1),
#  ('Hazar Gaddah', 1),
#  ('Heshmon', 1),
#  ('Beth Pelet', 1),
#  ('Hazar Shual', 1),
#  ('Biziothiah', 1),
#  ('Ezem', 1),
#  ('Eltolad', 1),
#  ('Kesil', 1),
#  ('Ziklag', 1),
#  ('Madmannah', 1),
#  ('Sansannah', 1),
#  ('Lebaoth', 1),
#  ('Shilhim', 1),
#  ('En Rimmon', 1),
#  ('Eshtaol', 1),
#  ('Zorah', 1),
#  ('Ashnah', 1),
#  ('Zanoah', 1),
#  ('En Gannim', 1),
#  ('Enam', 1),
#  ('Socoh', 1),
#  ('Shaaraim', 1),
#  ('Adithaim', 1),
#  ('Gederah', 1),
#  ('Gederothaim', 1),
#  ('Zenan', 1),
#  ('Hadashah', 1),
#  ('Migdal Gad', 1),
#  ('Dilean', 1),
#  ('Joktheel', 1),
#  ('Bozkath', 1),
#  ('Cabbon', 1),
#  ('Lahmas', 1),
#  ('Kitlish', 1),
#  ('Gederoth', 1),
#  ('Beth Dagon', 1),
#  ('Naamah', 1),
#  ('Ether', 1),
#  ('Ashan', 1),
#  ('Iphtah', 1),
#  ('Nezib', 1),
#  ('Keilah', 1),
#  ('Aczib', 1),
#  ('Mareshah', 1),
#  ('Shamir', 1),
#  ('Jattir', 1),
#  ('Dannah', 1),
#  ('Kiriath Sannah', 1),
#  ('Eshtemoa', 1),
#  ('Anim', 1),
#  ('Holon', 1),
#  ('Giloh', 1),
#  ('Arab', 1),
#  ('Rumah', 1),
#  ('Eshan', 1),
#  ('Janim', 1),
#  ('Beth Tappuah', 1),
#  ('Aphekah', 1),
#  ('Humtah', 1),
#  ('Zior', 1),
#  ('Maon', 1),
#  ('Juttah', 1),
#  ('Jokdeam', 1),
#  ('Kain', 1),
#  ('Gibeah', 1),
#  ('Halhul', 1),
#  ('Beth Zur', 1),
#  ('Gedor', 1),
#  ('Maarath', 1),
#  ('Beth Anoth', 1),
#  ('Eltekon', 1),
#  ('Kiriath Baal', 1),
#  ('Middin', 1),
#  ('Secacah', 1),
#  ('Nibshan', 1),
#  ('City of Salt', 1),
#  ('En Gedi', 1),
#  ('Ataroth Addar', 1),
#  ('Micmethath', 1),
#  ('Taanath Shiloh', 1),
#  ('Kanah', 1),
#  ('En Tappuah', 1),
#  ('Beth Shan', 1),
#  ('Ibleam', 1),
#  ('Endor', 1),
#  ('Geliloth', 1),
#  ('Emek Keziz', 1),
#  ('Parah', 1),
#  ('Ophrah', 1),
#  ('Ammoni', 1),
#  ('Ophni', 1),
#  ('Geba', 1),
#  ('Ramah', 1),
#  ('Mozah', 1),
#  ('Rekem', 1),
#  ('Irpeel', 1),
#  ('Taralah', 1),
#  ('Zela', 1),
#  ('Eleph', 1),
#  ('Gibeath', 1),
#  ('Kiriath', 1),
#  ('Balah', 1),
#  ('Bethuel', 1),
#  ('Hazar Susah', 1),
#  ('Beth Lebaoth', 1),
#  ('Sharuhen', 1),
#  ('Rimmon', 1),
#  ('Baalath Beer', 1),
#  ('Sarid', 1),
#  ('Maralah', 1),
#  ('Dabbesheth', 1),
#  ('Kisloth Tabor', 1),
#  ('Daberath', 1),
#  ('Japhia', 1),
#  ('Neah', 1),
#  ('Hannathon', 1),
#  ('Iphtah El', 1),
#  ('Kattath', 1),
#  ('Nahalal', 1),
#  ('Idalah', 1),
#  ('Kesulloth', 1),
#  ('Shunem', 1),
#  ('Hapharaim', 1),
#  ('Shion', 1),
#  ('Anaharath', 1),
#  ('Rabbith', 1),
#  ('Kishion', 1),
#  ('Ebez', 1),
#  ('Remeth', 1),
#  ('En Haddah', 1),
#  ('Beth Pazzez', 1),
#  ('Tabor', 1),
#  ('Shahazumah', 1),
#  ('Helkath', 1),
#  ('Hali', 1),
#  ('Beten', 1),
#  ('Allammelech', 1),
#  ('Amad', 1),
#  ('Mishal', 1),
#  ('Shihor Libnath', 1),
#  ('Beth Emek', 1),
#  ('Neiel', 1),
#  ('Cabul', 1),
#  ('Hammon', 1),
#  ('Tyrus', 1),
#  ('Hosah', 1),
#  ('Ummah', 1),
#  ('Heleph', 1),
#  ('Zaanannim', 1),
#  ('Adami-nekeb', 1),
#  ('Lakkum', 1),
#  ('Aznoth Tabor', 1),
#  ('Hukkok', 1),
#  ('Ziddim', 1),
#  ('Zer', 1),
#  ('Hammath', 1),
#  ('Rakkath', 1),
#  ('Adamah', 1),
#  ('En Hazor', 1),
#  ('Iron', 1),
#  ('Migdal El', 1),
#  ('Horem', 1),
#  ('Beth Anath', 1),
#  ('Ir Shemesh', 1),
#  ('Shaalabbin', 1),
#  ('Ithlah', 1),
#  ('Elon', 1),
#  ('Eltekeh', 1),
#  ('Gibbethon', 1),
#  ('Jehud', 1),
#  ('Bene Berak', 1),
#  ('Gath Rimmon', 1),
#  ('Jarkon', 1),
#  ('Rakkon', 1),
#  ('Joppa', 1),
#  ('Leshem', 1),
#  ('Timnath Serah', 1),
#  ('Galilee', 1),
#  ('Almon', 1),
#  ('Kibzaim', 1),
#  ('Be Eshtarah', 1),
#  ('Hammoth Dor', 1),
#  ('Kartan', 1),
#  ('Kartah', 1),
#  ('Dimnah', 1),
#  ('Gaash', 1),
#  ('Bezek', 1),
#  ('Zephath', 1),
#  ('Ashkelon', 1),
#  ('Kitron', 1),
#  ('Nahalol', 1),
#  ('Acco', 1),
#  ('Ahlab', 1),
#  ('Helbah', 1),
#  ('Mount Heres', 1),
#  ('Shaalbim', 1),
#  ('Sela', 1),
#  ('Bokim', 1),
#  ('Timnath Heres', 1),
#  ('Baal Hermon', 1),
#  ('Seirah', 1),
#  ('Harosheth Haggoyim', 1),
#  ('Kishon', 1),
#  ('Meroz', 1),
#  ('the spring of Harod', 1),
#  ('Beth Shittah', 1),
#  ('Zererah', 1),
#  ('Abel Meholah', 1),
#  ('Tabbath', 1),
#  ('Beth Barah', 1),
#  ('Karkor', 1),
#  ('the Pass of Heres', 1),
#  ('Tormah', 1),
#  ('Arumah', 1),
#  ('Zalmon', 1),
#  ('Thebez', 1),
#  ('Kamon', 1),
#  ('Tob', 1),
#  ('Minnith', 1),
#  ('Abel Keramim', 1),
#  ('Pirathon', 1),
#  ('Mahaneh Dan', 1),
#  ('Etam', 1),
#  ('Lehi', 1),
#  ('Sorek', 1),
#  ('Beth Rehob', 1),
#  ('Jebus', 1),
#  ('Baal Tamar', 1),
#  ('Gidom', 1),
#  ('Jabesh', 1),
#  ('Lebonah', 1),
#  ('Ebenezer', 1),
#  ('Beth Car', 1),
#  ('Shen', 1),
#  ('Shalisha', 1),
#  ('Shaalim', 1),
#  ('Zelzah', 1),
#  ('Shual', 1),
#  ('Zeboim', 1),
#  ('Migron', 1),
#  ('Bozez', 1),
#  ('Seneh', 1),
#  ('Zobah', 1),
#  ('Telaim', 1),
#  ('Ephes Dammim', 1),
#  ('Naioth', 1),
#  ('Secu', 1),
#  ('Nob', 1),
#  ('Hereth', 1),
#  ('Horesh', 1),
#  ('Hakilah', 1),
#  ('Gallim', 1),
#  ('Gilboa', 1),
#  ('Besor', 1),
#  ('Siphmoth', 1),
#  ('Racal', 1),
#  ('Bor Ashan', 1),
#  ('Athach', 1),
#  ('Helkath Hazzurim', 1),
#  ('Ammah', 1),
#  ('Giah', 1),
#  ('Bahurim', 1),
#  ('Sirah', 1),
#  ('Gittaim', 1),
#  ('Zion', 1),
#  ('Baal Perazim', 1),
#  ('Baalah of Judah', 1),
#  ('Perez Uzzah', 1),
#  ('Tebah', 1),
#  ('Berothai', 1),
#  ('the Valley of Salt', 1),
#  ('Lo Debar', 1),
#  ('Maacah', 1),
#  ('Helam', 1),
#  ('Baal Hazor', 1),
#  ('Tekoa', 1),
#  ('Kidron', 1),
#  ('Rogelim', 1),
#  ('Abel', 1),
#  ('Gob', 1),
#  ('Tahtim Hodshi', 1),
#  ('Zoheleth', 1),
#  ('Makaz', 1),
#  ('Bethhanan', 1),
#  ('Arubboth', 1),
#  ('Jokmeam', 1),
#  ('Tiphsah', 1),
#  ('Tadmor', 1),
#  ('Arabia', 1),
#  ('Zeredah', 1),
#  ('Ijon', 1),
#  ('Abel-beth-maacah', 1),
#  ('Kerith', 1),
#  ('Zarephath', 1),
#  ('Baal Shalishah', 1),
#  ('Amana', 1),
#  ('Pharpar', 1),
#  ('Ophel', 1),
#  ('Zair', 1),
#  ('Beth Haggan', 1),
#  ('the way up to Gur', 1),
#  ('Beth Eked of the Shepherds', 1),
#  ('Beth Eked', 1),
#  ('Sur', 1),
#  ('Silla', 1),
#  ('Gath Hepher', 1),
#  ('Kir', 1),
#  ('Halah', 1),
#  ('Habor', 1),
#  ('Gozan', 1),
#  ('Cuthah', 1),
#  ('Avva', 1),
#  ('Sepharvaim', 1),
#  ('Arpad', 1),
#  ('Hena', 1),
#  ('Ivvah', 1),
#  ('Rezeph', 1),
#  ('Telassar', 1),
#  ('Jotbah', 1),
#  ('Topheth', 1),
#  ('Shiloah', 1),
#  ('Carchemish', 1),
#  ('Calno', 1),
#  ('Aiath', 1),
#  ('Laishah', 1),
#  ('Madmenah', 1),
#  ('Gebim', 1),
#  ('Upper Egypt', 1),
#  ('Kir in Moab', 1),
#  ('Jahaz', 1),
#  ('Eglath Shelishiyah', 1),
#  ('Luhith', 1),
#  ('Horonaim', 1),
#  ('Nimrim', 1),
#  ('Eglaim', 1),
#  ('Beer Elim', 1),
#  ('Dimon', 1),
#  ('Perazim', 1),
#  ('<part of Jerusalem>', 1),
#  ('Hanes', 1),
#  ('<Egypt>', 1),
#  ('Aswan', 1),
#  ('Ephah', 1),
#  ('Tahpanhes', 1),
#  ('Beth Hakkerem', 1),
#  ('Uphaz', 1),
#  ('Uz', 1),
#  ('Buz', 1),
#  ('Sheshach', 1),
#  ('Hananel', 1),
#  ('Goah', 1),
#  ('Madmen', 1),
#  ('Beth Diblathaim', 1),
#  ('Beth Gamul', 1),
#  ('Beth Meon', 1),
#  ('Merathaim', 1),
#  ('Pekod', 1),
#  ('Minni', 1),
#  ('Kebar', 1),
#  ('Tel Abib', 1),
#  ('Arvad', 1),
#  ('Helech', 1),
#  ('Helbon', 1),
#  ('Zahar', 1),
#  ('Canneh', 1),
#  ('Kilmad', 1),
#  ('from Migdol to Aswan', 1),
#  ('Libya', 1),
#  ('Bubastis', 1),
#  ('Hamonah', 1),
#  ('En Eglaim', 1),
#  ('Hethlon', 1),
#  ('Berothah', 1),
#  ('Sibraim', 1),
#  ('Hauran', 1),
#  ('Tamar', 1),
#  ('Beth Arbel', 1),
#  ('the Valley of Aven', 1),
#  ('Beth Eden', 1),
#  ('Harmon', 1),
#  ('Karnaim', 1),
#  ('Sepharad', 1),
#  ('Aphrah', 1),
#  ('Shaphir', 1),
#  ('Zaanan', 1),
#  ('Beth Ezel', 1),
#  ('Maroth', 1),
#  ('Moresheth Gath', 1),
#  ('Hadrach', 1),
#  ('Azel', 1),
#  ('Gebal', 1),
#  ('Jaar', 1),
#  ('Bath Rabbim', 1),
#  ('Baal Hamon', 1),
#  ('India', 1),
#  ('Susa', 1),
#  ('Babylon', 1),
#  ('Judaea', 1),
#  ('Dura', 1),
#  ('Media', 1),
#  ('Persia', 1),
#  ('Ulai', 1),
#  ('Gibbar', 1),
#  ('Netophah', 1),
#  ('Lod', 1),
#  ('Hadid', 1),
#  ('Ono', 1),
#  ('Tel Melah', 1),
#  ('Tel Harsha', 1),
#  ('Kerub', 1),
#  ('Ecbatana', 1),
#  ('Ahava', 1),
#  ('Casiphia', 1),
#  ('the Jackal Well', 1),
#  ('the Hundred', 1),
#  ('Kephirim', 1),
#  ('Azmaveth', 1),
#  ('Jekabzeel', 1),
#  ('Jeshua', 1),
#  ('Meconah', 1),
#  ('Aiah', 1),
#  ('Ananiah', 1),
#  ('Neballat', 1),
#  ('Beth Gilgal', 1),
#  ('Pai', 1),
#  ('Jorkeam', 1),
#  ('Beth Gader', 1),
#  ('Atroth Beth Joab', 1),
#  ('Jabez', 1),
#  ('Ir Nahash', 1),
#  ('Recah', 1),
#  ('Lecah', 1),
#  ('Cozeba', 1),
#  ('Netaim', 1),
#  ('Bilhah', 1),
#  ('Tolad', 1),
#  ('Hazar Susim', 1),
#  ('Beth Biri', 1),
#  ('Token', 1),
#  ('Hara', 1),
#  ('Hilez', 1),
#  ('Alemeth', 1),
#  ('Aner', 1),
#  ('Bileam', 1),
#  ('Anem', 1),
#  ('Mashal', 1),
#  ('Hukok', 1),
#  ('Rimmono', 1),
#  ('Uzzen Sheerah', 1),
#  ('Naaran', 1),
#  ('Manahath', 1),
#  ('Tibhath', 1),
#  ('Cun', 1),
#  ('Aram Maacah', 1),
#  ('Shalleketh', 1),
#  ('Kue', 1),
#  ('Parvaim', 1),
#  ('Hamath Zobah', 1),
#  ('Adoraim', 1),
#  ('Jeshanah', 1),
#  ('Zephathah', 1),
#  ('Abel Maim', 1),
#  ('Ziz', 1),
#  ('Jeruel', 1),
#  ('Jabneh', 1),
#  ('Gur Baal', 1),
#  ('Gimzo', 1)]

# %% [markdown]
# #### Importing and mapping the OpenBible data set:

# %% [markdown]
# Characteristics of the [OpenBible geocoding](https://www.openbible.info/geo/) data set:
#
# Gps-coordinates:
# * ? means questionable
# * ~ means approximate
# * '>' means the location surronds the given point
# * '<' means the location is inside the city given
#
# In this notebook gps-coordinates marked with either ? or ~ are always treated as questionable and thus given the comment '?'. All characters except for numbers are then stripped for the coordinates in order to visualize the data.

# %%
file = 'openbible_data.txt'

openbible_dict = {}

with open(file) as f:
    next(f)
    next(f)
    reader = csv.reader(f, delimiter='\t')
    for r in reader:
        name = r[0]
        root = r[1]
        gps = (r[2], r[3])
        openbible_dict[name] = [root, gps]
        
len(openbible_dict)
# Out:
# 1274

# %%
#openbible_dict

# %% [markdown]
# Finding out how many cooccurences we have between the ETCBC database and the OpenBible data set in terms of shared glosses:

# %%
n = 0

for topo in topo_dict:
    if topo_dict[topo] in openbible_dict:
        n += 1

print(f'Shared glosses: {n}')
# Out:
# Shared glosses: 524

# %%
def cleanGPS(c):
    uncertain = ''
    comment = ''
    if c in ['?', '-']:
        uncertain = '?'
        c = ''
    if '?' in c:
        uncertain = '?'
        c = c.rstrip('?')
    if '~' in c:
        uncertain = '?'
        c = re.sub('~', '', c)
    if '<' in c:
        comment += '<'
        c = re.sub('<', '', c)
    if '>' in c:
        comment += '>'
        c = re.sub('>', '', c)
    return [c, uncertain, comment]

# %%
geo_coding = []

for topo in topo_dict:
    dic = {}
    if topo_dict[topo] in openbible_dict:
        name = topo_dict[topo]
        modern_name = ''
        gps = openbible_dict[topo_dict[topo]][1]

        gps_lat = cleanGPS(gps[0])
        gps_lon = cleanGPS(gps[1])
        
        #Uncertain:
        if gps_lat[1] != '':
            uncertain = gps_lat[1]
        elif gps_lon[1] != '':
            uncertain = gps_lon[1]
        else:
            uncertain = ''
            
        #Comment:
        if gps_lat[2] != '':
            comment = gps_lat[2]
        else:
            comment = ''
        
        gps = (gps_lat[0],gps_lon[0])
        if gps != ('',''):
            gps = float(gps[0]), float(gps[1])
            dic['name'] = name
            dic['modern name'] = modern_name
            dic['gps'] = gps
            dic['uncertain'] = uncertain
            dic['comment'] = comment
            geo_coding.append(dic)
            
len(geo_coding)
# Out:
# 516

# %% [markdown]
# For now, I only want to use those locations that are supposedly not ambigous:

# %%
count = 0

for l in geo_coding:
    if l['uncertain'] != '?':
        count += 1

print(f'Certain loctions: {count}')
# Out:
# Certain loctions: 354

# %%
name_list = []

for l in geo_coding:
    name_list.append(l['name'])
    
collections.Counter(name_list).most_common()
# Out:
# [('Damascus', 3),
#  ('Egypt', 2),
#  ('Sheba', 2),
#  ('Shiloh', 2),
#  ('Sin', 2),
#  ('Jerusalem', 2),
#  ('Dor', 2),
#  ('Abdon', 2),
#  ('Samaria', 2),
#  ('Memphis', 2),
#  ('Thebes', 2),
#  ('Cush', 1),
#  ('Tigris', 1),
#  ('Asshur', 1),
#  ('Euphrates', 1),
#  ('Ararat', 1),
#  ('Magog', 1),
#  ('Elishah', 1),
#  ('Tarshish', 1),
#  ('Dedan', 1),
#  ('Babel', 1),
#  ('Erech', 1),
#  ('Calneh', 1),
#  ('Shinar', 1),
#  ('Nineveh', 1),
#  ('Calah', 1),
#  ('Resen', 1),
#  ('Sidon', 1),
#  ('Gerar', 1),
#  ('Gaza', 1),
#  ('Sodom', 1),
#  ('Gomorrah', 1),
#  ('Admah', 1),
#  ('Zeboiim', 1),
#  ('Lasha', 1),
#  ('Aram', 1),
#  ('Mesha', 1),
#  ('Sephar', 1),
#  ('Ur', 1),
#  ('Shechem', 1),
#  ('Jordan', 1),
#  ('Zoar', 1),
#  ('Mamre', 1),
#  ('Hebron', 1),
#  ('Ellasar', 1),
#  ('Bela', 1),
#  ('Seir', 1),
#  ('Hobah', 1),
#  ('Salem', 1),
#  ('Shur', 1),
#  ('Bered', 1),
#  ('Paran', 1),
#  ('Moriah', 1),
#  ('Machpelah', 1),
#  ('Mesopotamia', 1),
#  ('Tema', 1),
#  ('Edom', 1),
#  ('Esek', 1),
#  ('Sitnah', 1),
#  ('Shibah', 1),
#  ('Gilead', 1),
#  ('Galeed', 1),
#  ('Mahanaim', 1),
#  ('Jabbok', 1),
#  ('Peniel', 1),
#  ('Teman', 1),
#  ('Dinhabah', 1),
#  ('Avith', 1),
#  ('Masrekah', 1),
#  ('Pau', 1),
#  ('Dothan', 1),
#  ('Enaim', 1),
#  ('Nile', 1),
#  ('Rameses', 1),
#  ('Pithom', 1),
#  ('Horeb', 1),
#  ('Etham', 1),
#  ('Migdol', 1),
#  ('Philistia', 1),
#  ('Marah', 1),
#  ('Elim', 1),
#  ('Sinai', 1),
#  ('Rephidim', 1),
#  ('Massah', 1),
#  ('Taberah', 1),
#  ('Hazeroth', 1),
#  ('Hamath', 1),
#  ('Zoan', 1),
#  ('Hormah', 1),
#  ('Arad', 1),
#  ('Atharim', 1),
#  ('Oboth', 1),
#  ('Zered', 1),
#  ('Arnon', 1),
#  ('Waheb', 1),
#  ('Suphah', 1),
#  ('Ar', 1),
#  ('Beer', 1),
#  ('Mattanah', 1),
#  ('Nahaliel', 1),
#  ('Bamoth', 1),
#  ('Pisgah', 1),
#  ('Jeshimon', 1),
#  ('Jahzah', 1),
#  ('Heshbon', 1),
#  ('Nophah', 1),
#  ('Medeba', 1),
#  ('Jazer', 1),
#  ('Bashan', 1),
#  ('Edrei', 1),
#  ('Jericho', 1),
#  ('Pethor', 1),
#  ('Peor', 1),
#  ('Shittim', 1),
#  ('Abarim', 1),
#  ('Nimrah', 1),
#  ('Elealeh', 1),
#  ('Sebam', 1),
#  ('Beon', 1),
#  ('Jogbehah', 1),
#  ('Sibmah', 1),
#  ('Kenath', 1),
#  ('Nobah', 1),
#  ('Dophkah', 1),
#  ('Alush', 1),
#  ('Rithmah', 1),
#  ('Rissah', 1),
#  ('Kehelathah', 1),
#  ('Haradah', 1),
#  ('Makheloth', 1),
#  ('Tahath', 1),
#  ('Terah', 1),
#  ('Hashmonah', 1),
#  ('Moseroth', 1),
#  ('Jotbathah', 1),
#  ('Abronah', 1),
#  ('Zalmonah', 1),
#  ('Punon', 1),
#  ('Iyim', 1),
#  ('Azmon', 1),
#  ('Zedad', 1),
#  ('Ziphron', 1),
#  ('Shepham', 1),
#  ('Suph', 1),
#  ('Tophel', 1),
#  ('Laban', 1),
#  ('Dizahab', 1),
#  ('Ashtaroth', 1),
#  ('Lebanon', 1),
#  ('Elath', 1),
#  ('Caphtor', 1),
#  ('Kedemoth', 1),
#  ('Argob', 1),
#  ('Hermon', 1),
#  ('Sirion', 1),
#  ('Senir', 1),
#  ('Salecah', 1),
#  ('Golan', 1),
#  ('Moserah', 1),
#  ('Adam', 1),
#  ('Zarethan', 1),
#  ('Shebarim', 1),
#  ('Gibeon', 1),
#  ('Beeroth', 1),
#  ('Lachish', 1),
#  ('Eglon', 1),
#  ('Azekah', 1),
#  ('Makkedah', 1),
#  ('Aijalon', 1),
#  ('Gezer', 1),
#  ('Madon', 1),
#  ('Shimron', 1),
#  ('Merom', 1),
#  ('Anab', 1),
#  ('Gath', 1),
#  ('Ashdod', 1),
#  ('Geder', 1),
#  ('Adullam', 1),
#  ('Hepher', 1),
#  ('Taanach', 1),
#  ('Megiddo', 1),
#  ('Jokneam', 1),
#  ('Carmel', 1),
#  ('Tirzah', 1),
#  ('Shihor', 1),
#  ('Ekron', 1),
#  ('Mearah', 1),
#  ('Geshur', 1),
#  ('Mephaath', 1),
#  ('Rabbah', 1),
#  ('Betonim', 1),
#  ('Zaphon', 1),
#  ('Hezron', 1),
#  ('Karka', 1),
#  ('Nephtoah', 1),
#  ('Shikkeron', 1),
#  ('Kabzeel', 1),
#  ('Jagur', 1),
#  ('Kinah', 1),
#  ('Dimonah', 1),
#  ('Adadah', 1),
#  ('Ithnan', 1),
#  ('Telem', 1),
#  ('Bealoth', 1),
#  ('Kerioth', 1),
#  ('Amam', 1),
#  ('Shema', 1),
#  ('Moladah', 1),
#  ('Heshmon', 1),
#  ('Biziothiah', 1),
#  ('Ezem', 1),
#  ('Eltolad', 1),
#  ('Ziklag', 1),
#  ('Madmannah', 1),
#  ('Sansannah', 1),
#  ('Lebaoth', 1),
#  ('Shilhim', 1),
#  ('Eshtaol', 1),
#  ('Zorah', 1),
#  ('Ashnah', 1),
#  ('Enam', 1),
#  ('Adithaim', 1),
#  ('Gederah', 1),
#  ('Gederothaim', 1),
#  ('Zenan', 1),
#  ('Hadashah', 1),
#  ('Dilean', 1),
#  ('Bozkath', 1),
#  ('Cabbon', 1),
#  ('Gederoth', 1),
#  ('Naamah', 1),
#  ('Ether', 1),
#  ('Ashan', 1),
#  ('Iphtah', 1),
#  ('Nezib', 1),
#  ('Keilah', 1),
#  ('Mareshah', 1),
#  ('Jattir', 1),
#  ('Dannah', 1),
#  ('Eshtemoa', 1),
#  ('Anim', 1),
#  ('Giloh', 1),
#  ('Arab', 1),
#  ('Rumah', 1),
#  ('Eshan', 1),
#  ('Janim', 1),
#  ('Aphekah', 1),
#  ('Humtah', 1),
#  ('Zior', 1),
#  ('Maon', 1),
#  ('Juttah', 1),
#  ('Jokdeam', 1),
#  ('Kain', 1),
#  ('Halhul', 1),
#  ('Maarath', 1),
#  ('Eltekon', 1),
#  ('Middin', 1),
#  ('Secacah', 1),
#  ('Nibshan', 1),
#  ('City of Salt', 1),
#  ('Ibleam', 1),
#  ('Geliloth', 1),
#  ('Parah', 1),
#  ('Ophni', 1),
#  ('Mozah', 1),
#  ('Rekem', 1),
#  ('Irpeel', 1),
#  ('Taralah', 1),
#  ('Zela', 1),
#  ('Balah', 1),
#  ('Bethuel', 1),
#  ('Sharuhen', 1),
#  ('Sarid', 1),
#  ('Dabbesheth', 1),
#  ('Daberath', 1),
#  ('Japhia', 1),
#  ('Neah', 1),
#  ('Hannathon', 1),
#  ('Kattath', 1),
#  ('Nahalal', 1),
#  ('Idalah', 1),
#  ('Shunem', 1),
#  ('Hapharaim', 1),
#  ('Shion', 1),
#  ('Anaharath', 1),
#  ('Rabbith', 1),
#  ('Kishion', 1),
#  ('Ebez', 1),
#  ('Remeth', 1),
#  ('Shahazumah', 1),
#  ('Helkath', 1),
#  ('Hali', 1),
#  ('Beten', 1),
#  ('Allammelech', 1),
#  ('Amad', 1),
#  ('Mishal', 1),
#  ('Neiel', 1),
#  ('Hammon', 1),
#  ('Hosah', 1),
#  ('Ummah', 1),
#  ('Heleph', 1),
#  ('Zaanannim', 1),
#  ('Adami-nekeb', 1),
#  ('Lakkum', 1),
#  ('Hukkok', 1),
#  ('Ziddim', 1),
#  ('Zer', 1),
#  ('Hammath', 1),
#  ('Rakkath', 1),
#  ('Adamah', 1),
#  ('Horem', 1),
#  ('Shaalabbin', 1),
#  ('Ithlah', 1),
#  ('Elon', 1),
#  ('Eltekeh', 1),
#  ('Gibbethon', 1),
#  ('Jehud', 1),
#  ('Rakkon', 1),
#  ('Joppa', 1),
#  ('Leshem', 1),
#  ('Galilee', 1),
#  ('Almon', 1),
#  ('Kibzaim', 1),
#  ('Kartan', 1),
#  ('Kartah', 1),
#  ('Dimnah', 1),
#  ('Gaash', 1),
#  ('Zephath', 1),
#  ('Ashkelon', 1),
#  ('Kitron', 1),
#  ('Nahalol', 1),
#  ('Acco', 1),
#  ('Ahlab', 1),
#  ('Helbah', 1),
#  ('Mount Heres', 1),
#  ('Shaalbim', 1),
#  ('Sela', 1),
#  ('Seirah', 1),
#  ('Kishon', 1),
#  ('Meroz', 1),
#  ('Zererah', 1),
#  ('Tabbath', 1),
#  ('Karkor', 1),
#  ('Arumah', 1),
#  ('Zalmon', 1),
#  ('Thebez', 1),
#  ('Kamon', 1),
#  ('Tob', 1),
#  ('Minnith', 1),
#  ('Pirathon', 1),
#  ('Lehi', 1),
#  ('Jebus', 1),
#  ('Gidom', 1),
#  ('Jabesh', 1),
#  ('Lebonah', 1),
#  ('Ebenezer', 1),
#  ('Shen', 1),
#  ('Shaalim', 1),
#  ('Zelzah', 1),
#  ('Shual', 1),
#  ('Zeboim', 1),
#  ('Migron', 1),
#  ('Bozez', 1),
#  ('Seneh', 1),
#  ('Zobah', 1),
#  ('Telaim', 1),
#  ('Naioth', 1),
#  ('Secu', 1),
#  ('Nob', 1),
#  ('Hereth', 1),
#  ('Horesh', 1),
#  ('Gallim', 1),
#  ('Gilboa', 1),
#  ('Besor', 1),
#  ('Siphmoth', 1),
#  ('Racal', 1),
#  ('Ammah', 1),
#  ('Giah', 1),
#  ('Bahurim', 1),
#  ('Sirah', 1),
#  ('Gittaim', 1),
#  ('Zion', 1),
#  ('Berothai', 1),
#  ('Maacah', 1),
#  ('Helam', 1),
#  ('Tekoa', 1),
#  ('Kidron', 1),
#  ('Rogelim', 1),
#  ('Abel', 1),
#  ('Gob', 1),
#  ('Makaz', 1),
#  ('Arubboth', 1),
#  ('Tadmor', 1),
#  ('Arabia', 1),
#  ('Ijon', 1),
#  ('Abel-beth-maacah', 1),
#  ('Zarephath', 1),
#  ('Amana', 1),
#  ('Pharpar', 1),
#  ('Ophel', 1),
#  ('Zair', 1),
#  ('Sur', 1),
#  ('Silla', 1),
#  ('Kir', 1),
#  ('Halah', 1),
#  ('Habor', 1),
#  ('Gozan', 1),
#  ('Cuthah', 1),
#  ('Avva', 1),
#  ('Sepharvaim', 1),
#  ('Arpad', 1),
#  ('Hena', 1),
#  ('Ivvah', 1),
#  ('Rezeph', 1),
#  ('Telassar', 1),
#  ('Jotbah', 1),
#  ('Topheth', 1),
#  ('Shiloah', 1),
#  ('Carchemish', 1),
#  ('Calno', 1),
#  ('Aiath', 1),
#  ('Laishah', 1),
#  ('Madmenah', 1),
#  ('Gebim', 1),
#  ('Jahaz', 1),
#  ('Luhith', 1),
#  ('Horonaim', 1),
#  ('Nimrim', 1),
#  ('Eglaim', 1),
#  ('Hanes', 1),
#  ('Ephah', 1),
#  ('Tahpanhes', 1),
#  ('Uphaz', 1),
#  ('Uz', 1),
#  ('Buz', 1),
#  ('Goah', 1),
#  ('Merathaim', 1),
#  ('Pekod', 1),
#  ('Minni', 1),
#  ('Arvad', 1),
#  ('Helech', 1),
#  ('Helbon', 1),
#  ('Canneh', 1),
#  ('Libya', 1),
#  ('Hamonah', 1),
#  ('Hethlon', 1),
#  ('Berothah', 1),
#  ('Sibraim', 1),
#  ('Hauran', 1),
#  ('Harmon', 1),
#  ('Karnaim', 1),
#  ('Sepharad', 1),
#  ('Shaphir', 1),
#  ('Zaanan', 1),
#  ('Maroth', 1),
#  ('Hadrach', 1),
#  ('Gebal', 1),
#  ('Jaar', 1),
#  ('India', 1),
#  ('Susa', 1),
#  ('Babylon', 1),
#  ('Dura', 1),
#  ('Media', 1),
#  ('Persia', 1),
#  ('Ulai', 1),
#  ('Netophah', 1),
#  ('Lod', 1),
#  ('Hadid', 1),
#  ('Ono', 1),
#  ('Ecbatana', 1),
#  ('Ahava', 1),
#  ('Casiphia', 1),
#  ('Azmaveth', 1),
#  ('Jekabzeel', 1),
#  ('Jeshua', 1),
#  ('Meconah', 1),
#  ('Ananiah', 1),
#  ('Neballat', 1),
#  ('Pai', 1),
#  ('Jabez', 1),
#  ('Recah', 1),
#  ('Cozeba', 1),
#  ('Netaim', 1),
#  ('Bilhah', 1),
#  ('Tolad', 1),
#  ('Hara', 1),
#  ('Alemeth', 1),
#  ('Aner', 1),
#  ('Bileam', 1),
#  ('Anem', 1),
#  ('Mashal', 1),
#  ('Hukok', 1),
#  ('Rimmono', 1),
#  ('Naaran', 1),
#  ('Manahath', 1),
#  ('Tibhath', 1),
#  ('Cun', 1),
#  ('Kue', 1),
#  ('Adoraim', 1),
#  ('Jeshanah', 1),
#  ('Ziz', 1),
#  ('Jeruel', 1),
#  ('Jabneh', 1),
#  ('Gimzo', 1)]

# %% [markdown]
# Creating dictionary for export as TF-feature:

# %%
c = 0
lat_dict = {}
long_dict = {}

for n in topo_dict:
    gloss = topo_dict[n]
    node = n
    for l in geo_coding:
        if gloss == l['name'] and l['uncertain'] != '?':
            gps = l['gps']
            lat_dict[node] = str(gps[0])
            long_dict[node] = str(gps[1])
            c += 1

print(c)
print(len(lat_dict))
# Out:
# 380
# 354

# %% [markdown]
# #### Exporting as TF-feature

# %%
if 'SCRIPT' not in locals():
    SCRIPT = False
    FORCE = True
    CORE_NAME = 'bhsa'
    NAME = 'gps'
    VERSION= 'c'
    CORE_MODULE = 'core'

# %%
repoBase = os.path.expanduser('~/text-fabric-data/etcbc')
coreRepo = '{}/{}'.format(repoBase, CORE_NAME)
thisRepo = '{}/{}'.format(repoBase, NAME)

coreTf = '{}/tf/{}'.format(coreRepo, VERSION)

thisSource = '{}/source/{}'.format(thisRepo, VERSION)
thisTemp = '{}/_temp/{}'.format(thisRepo, VERSION)
thisTempTf = '{}/tf'.format(thisTemp)

thisTf = '{}/tf/{}'.format(thisRepo, VERSION)
thisNotes = '{}/shebanq/{}'.format(thisRepo, VERSION)

# %% [markdown]
# Exporting latitude feature:

# %%
nodeFeatures_lat = dict(lat=lat_dict)
metaData_lat = dict(
    lat=dict(
        valueType='str',
        description='Latitude of topological lexemes. The geocoding is retrieved from the data set available at https://www.openbible.info/geo/data/merged.txt',
        coreData='BHSA',
        coreVersion=VERSION
    )
)
TF = Fabric(locations=thisTempTf, silent=True)
TF.save(nodeFeatures=nodeFeatures, edgeFeatures={}, metaData=metaData)
# Out:
# {'gps': [{'name': 'Amam',
#    'modern name': '',
#    'gps': (31.162327, 35.057114),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Karka',
#    'modern name': '',
#    'gps': (30.958506, 34.3805),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Hara',
#    'modern name': '',
#    'gps': (36.344972, 40.789333),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Cuthah',
#    'modern name': '',
#    'gps': (32.733333, 44.666667),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Memphis',
#    'modern name': '',
#    'gps': (29.849632, 31.253958),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Helkath',
#    'modern name': '',
#    'gps': (32.955448, 35.211971),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Arumah',
#    'modern name': '',
#    'gps': (32.154887, 35.318192),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Almon',
#    'modern name': '',
#    'gps': (31.828406, 35.287637),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Shechem',
#    'modern name': '',
#    'gps': (32.21369123124062, 35.2817986718367),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Bamoth',
#    'modern name': '',
#    'gps': (31.76503129703305, 35.71856575741812),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Maarath',
#    'modern name': '',
#    'gps': (31.621003, 35.102328),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Jeruel',
#    'modern name': '',
#    'gps': (31.572903, 35.406346),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Shimron',
#    'modern name': '',
#    'gps': (32.70528895585606, 35.21333285757741),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Lebonah',
#    'modern name': '',
#    'gps': (32.07077, 35.239871),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Lachish',
#    'modern name': '',
#    'gps': (31.56485056116292, 34.8467256730566),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Aram',
#    'modern name': '',
#    'gps': (34.85, 39.12),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Rissah',
#    'modern name': '',
#    'gps': (30.317396, 35.407152),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Ashnah',
#    'modern name': '',
#    'gps': (31.8099, 34.9365),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Taralah',
#    'modern name': '',
#    'gps': (31.792733, 35.196862),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Beten',
#    'modern name': '',
#    'gps': (32.934736, 35.270799),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Tekoa',
#    'modern name': '',
#    'gps': (31.63622127191993, 35.21407721824517),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Bileam',
#    'modern name': '',
#    'gps': (32.45, 35.2833),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Admah',
#    'modern name': '',
#    'gps': (31.11942270162137, 35.41253049195169),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Azmaveth',
#    'modern name': '',
#    'gps': (31.834203, 35.260706),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Goah',
#    'modern name': '',
#    'gps': (31.777444, 35.234935),
#    'uncertain': '',
#    'comment': '<'},
#   {'name': 'Lebanon',
#    'modern name': '',
#    'gps': (33.752479, 35.590804),
#    'uncertain': '',
#    'comment': '>'},
#   {'name': 'Canneh',
#    'modern name': '',
#    'gps': (32.127213, 45.229995),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Ananiah',
#    'modern name': '',
#    'gps': (31.83291, 35.219683),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'India',
#    'modern name': '',
#    'gps': (22.0, 77.0),
#    'uncertain': '',
#    'comment': '>'},
#   {'name': 'Mattanah',
#    'modern name': '',
#    'gps': (31.718148, 35.584826),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Irpeel',
#    'modern name': '',
#    'gps': (31.869343, 35.197712),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Gederah',
#    'modern name': '',
#    'gps': (31.823337, 34.777779),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Sepharvaim',
#    'modern name': '',
#    'gps': (33.789693, 44.459399),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Nahalol',
#    'modern name': '',
#    'gps': (32.722209, 35.35282),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Ashtaroth',
#    'modern name': '',
#    'gps': (32.8333333333, 36.0166666667),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Humtah',
#    'modern name': '',
#    'gps': (31.53577362133176, 35.09409986578734),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Madon',
#    'modern name': '',
#    'gps': (32.799879, 35.459506),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Seirah',
#    'modern name': '',
#    'gps': (31.93053920580005, 35.22103274923676),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Hethlon',
#    'modern name': '',
#    'gps': (34.73799, 36.340918),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Sirion',
#    'modern name': '',
#    'gps': (33.41615982399708, 35.85725617635589),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Taanach',
#    'modern name': '',
#    'gps': (32.51723975501718, 35.21632508826309),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Jordan',
#    'modern name': '',
#    'gps': (32.309099, 35.5599),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Jerusalem',
#    'modern name': '',
#    'gps': (31.777444, 35.234935),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Moriah',
#    'modern name': '',
#    'gps': (31.77759385009378, 35.23525140955081),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Gebim',
#    'modern name': '',
#    'gps': (31.8, 35.25),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Hauran',
#    'modern name': '',
#    'gps': (32.80007552505443, 35.93730130476259),
#    'uncertain': '',
#    'comment': '>'},
#   {'name': 'Susa',
#    'modern name': '',
#    'gps': (32.18919123705116, 48.25788647687722),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Magog',
#    'modern name': '',
#    'gps': (46.0, 47.0),
#    'uncertain': '?',
#    'comment': '>'},
#   {'name': 'Mount Heres',
#    'modern name': '',
#    'gps': (31.75274835811488, 34.97660913147738),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Nile',
#    'modern name': '',
#    'gps': (30.092632, 31.230987),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Uphaz',
#    'modern name': '',
#    'gps': (22.0, 77.0),
#    'uncertain': '',
#    'comment': '>'},
#   {'name': 'Terah',
#    'modern name': '',
#    'gps': (30.317396, 35.407152),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Kibzaim',
#    'modern name': '',
#    'gps': (31.833333, 35.3),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Ur',
#    'modern name': '',
#    'gps': (30.9620520474569, 46.10374195774169),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Madmannah',
#    'modern name': '',
#    'gps': (31.391668, 34.940502),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Giloh',
#    'modern name': '',
#    'gps': (31.616667, 35.083333),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Zeboim',
#    'modern name': '',
#    'gps': (31.10182240291489, 35.47633656511371),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Paran',
#    'modern name': '',
#    'gps': (29.151667, 33.541944),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Rezeph',
#    'modern name': '',
#    'gps': (35.95, 39.016667),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Abarim',
#    'modern name': '',
#    'gps': (31.76135780447535, 35.74614824478083),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Gaash',
#    'modern name': '',
#    'gps': (32.121473, 35.150392),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Eglaim',
#    'modern name': '',
#    'gps': (30.998062, 35.498547),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Heleph',
#    'modern name': '',
#    'gps': (33.134416, 35.332157),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Dor',
#    'modern name': '',
#    'gps': (32.61323618394521, 34.91889683434057),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Geshur',
#    'modern name': '',
#    'gps': (33.0, 36.41667),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Sarid',
#    'modern name': '',
#    'gps': (32.68978573733861, 35.19666870006055),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Calah',
#    'modern name': '',
#    'gps': (36.142884, 43.312178),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Heshbon',
#    'modern name': '',
#    'gps': (31.80052000870321, 35.80901866717255),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Jaar',
#    'modern name': '',
#    'gps': (31.771104, 34.993812),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Mozah',
#    'modern name': '',
#    'gps': (31.802641, 35.158376),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Gebal',
#    'modern name': '',
#    'gps': (34.11910360710159, 35.6461419556213),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Mamre',
#    'modern name': '',
#    'gps': (31.54909871686872, 35.09356062020027),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Seir',
#    'modern name': '',
#    'gps': (30.734691, 35.60625),
#    'uncertain': '',
#    'comment': '>'},
#   {'name': 'Thebes',
#    'modern name': '',
#    'gps': (25.700025, 32.639441),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Gerar',
#    'modern name': '',
#    'gps': (31.39129109635703, 34.56057015639144),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Shihor',
#    'modern name': '',
#    'gps': (31.032047, 33.854957),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Dilean',
#    'modern name': '',
#    'gps': (31.56485056116292, 34.8467256730566),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Keilah',
#    'modern name': '',
#    'gps': (31.614175, 35.002752),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Naioth',
#    'modern name': '',
#    'gps': (31.83273947023218, 35.1801628605877),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Jeshanah',
#    'modern name': '',
#    'gps': (31.980029, 35.229709),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Jehud',
#    'modern name': '',
#    'gps': (32.033636, 34.889599),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Jebus',
#    'modern name': '',
#    'gps': (31.777444, 35.234935),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Ashkelon',
#    'modern name': '',
#    'gps': (31.66240510553615, 34.54722773494757),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Hali',
#    'modern name': '',
#    'gps': (32.934736, 35.270799),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Rumah',
#    'modern name': '',
#    'gps': (32.154887, 35.318192),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Geliloth',
#    'modern name': '',
#    'gps': (31.86378328132916, 35.51854651224448),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Hannathon',
#    'modern name': '',
#    'gps': (32.916002, 35.426637),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Bilhah',
#    'modern name': '',
#    'gps': (31.24495217357714, 34.8408885849849),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Rakkath',
#    'modern name': '',
#    'gps': (32.79553799444466, 35.52922039819518),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Shiloah',
#    'modern name': '',
#    'gps': (31.777444, 35.234935),
#    'uncertain': '',
#    'comment': '<'},
#   {'name': 'Bela',
#    'modern name': '',
#    'gps': (30.9265225301655, 35.4190606947832),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Dura',
#    'modern name': '',
#    'gps': (32.53650368616845, 44.42088287373876),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Rithmah',
#    'modern name': '',
#    'gps': (31.8099, 34.9365),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Abronah',
#    'modern name': '',
#    'gps': (29.75804307645581, 35.0306017443078),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Janim',
#    'modern name': '',
#    'gps': (31.516667, 35.166667),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Zer',
#    'modern name': '',
#    'gps': (33.125828, 35.165),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Zela',
#    'modern name': '',
#    'gps': (31.792733, 35.196862),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Gidom',
#    'modern name': '',
#    'gps': (31.93466, 35.297063),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Avva',
#    'modern name': '',
#    'gps': (34.467725, 41.964955),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Sidon',
#    'modern name': '',
#    'gps': (33.56316734135746, 35.36634649354799),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Merathaim',
#    'modern name': '',
#    'gps': (32.53650368616845, 44.42088287373876),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Naamah',
#    'modern name': '',
#    'gps': (31.871782, 34.871894),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Sheba',
#    'modern name': '',
#    'gps': (9.022736, 38.746799),
#    'uncertain': '',
#    'comment': '>'},
#   {'name': 'Nobah',
#    'modern name': '',
#    'gps': (32.756919, 36.6164),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Kinah',
#    'modern name': '',
#    'gps': (31.1858, 34.96745),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Siphmoth',
#    'modern name': '',
#    'gps': (31.373521, 35.074552),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Nophah',
#    'modern name': '',
#    'gps': (32.756919, 36.6164),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Sepharad',
#    'modern name': '',
#    'gps': (38.47682690345803, 28.11413118732089),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Nahaliel',
#    'modern name': '',
#    'gps': (31.718148, 35.584826),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Azekah',
#    'modern name': '',
#    'gps': (31.70063856043753, 34.93618589974822),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Elealeh',
#    'modern name': '',
#    'gps': (31.813796, 35.824275),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Ekron',
#    'modern name': '',
#    'gps': (31.77761410537458, 34.85214575880509),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Maacah',
#    'modern name': '',
#    'gps': (33.2, 36.5),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Hadashah',
#    'modern name': '',
#    'gps': (31.679512, 34.695903),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Berothai',
#    'modern name': '',
#    'gps': (33.93148, 36.152049),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Nahalal',
#    'modern name': '',
#    'gps': (32.722209, 35.35282),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Jekabzeel',
#    'modern name': '',
#    'gps': (31.1858, 34.96745),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Ivvah',
#    'modern name': '',
#    'gps': (34.467725, 41.964955),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Tigris',
#    'modern name': '',
#    'gps': (35.983343, 43.346466),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Adami-nekeb',
#    'modern name': '',
#    'gps': (32.6105, 35.54289),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Pethor',
#    'modern name': '',
#    'gps': (36.654616, 38.068879),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Karkor',
#    'modern name': '',
#    'gps': (32.1843727808126, 35.70287002746794),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Ahlab',
#    'modern name': '',
#    'gps': (33.02498036359259, 35.44544657992798),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Eglon',
#    'modern name': '',
#    'gps': (31.5, 34.7667),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Abdon',
#    'modern name': '',
#    'gps': (33.047808, 35.146201),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Netophah',
#    'modern name': '',
#    'gps': (31.735465, 35.220503),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Edrei',
#    'modern name': '',
#    'gps': (32.62413707696097, 36.09899663593119),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Sansannah',
#    'modern name': '',
#    'gps': (31.391668, 34.940502),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Gederoth',
#    'modern name': '',
#    'gps': (31.823337, 34.777779),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Carchemish',
#    'modern name': '',
#    'gps': (36.82928161099629, 38.01576051001015),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Sibraim',
#    'modern name': '',
#    'gps': (35.136204, 36.749488),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Kishion',
#    'modern name': '',
#    'gps': (32.559061, 35.246206),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Meroz',
#    'modern name': '',
#    'gps': (32.68695640243183, 35.39091304299688),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Zaanan',
#    'modern name': '',
#    'gps': (31.743719, 34.694006),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Resen',
#    'modern name': '',
#    'gps': (36.35941, 43.152887),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Shion',
#    'modern name': '',
#    'gps': (32.716666, 35.333334),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Jogbehah',
#    'modern name': '',
#    'gps': (32.028743, 35.862887),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Betonim',
#    'modern name': '',
#    'gps': (32.0105, 35.706297),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Lebaoth',
#    'modern name': '',
#    'gps': (31.391668, 34.940502),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Sibmah',
#    'modern name': '',
#    'gps': (31.815283, 35.766738),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Tahath',
#    'modern name': '',
#    'gps': (30.317396, 35.407152),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Zorah',
#    'modern name': '',
#    'gps': (31.762141, 34.969319),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Ammah',
#    'modern name': '',
#    'gps': (31.869005, 35.343177),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Salem',
#    'modern name': '',
#    'gps': (31.777444, 35.234935),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Casiphia',
#    'modern name': '',
#    'gps': (35.136204, 36.749488),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Ziklag',
#    'modern name': '',
#    'gps': (31.37760000000001, 34.87356199999998),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Zair',
#    'modern name': '',
#    'gps': (30.9265225301655, 35.4190606947832),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Eltekeh',
#    'modern name': '',
#    'gps': (31.869521, 35.06688),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Marah',
#    'modern name': '',
#    'gps': (29.35, 32.933333),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Zion',
#    'modern name': '',
#    'gps': (31.777444, 35.234935),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Dothan',
#    'modern name': '',
#    'gps': (32.42064338380848, 35.18019829952955),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Halhul',
#    'modern name': '',
#    'gps': (31.579549, 35.099103),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Tadmor',
#    'modern name': '',
#    'gps': (34.5540491686839, 38.26590497164145),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Adoraim',
#    'modern name': '',
#    'gps': (31.51666666666667, 34.98333333333333),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Sinai',
#    'modern name': '',
#    'gps': (28.539722, 33.973333),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Hosah',
#    'modern name': '',
#    'gps': (32.178502, 35.22758),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Ebenezer',
#    'modern name': '',
#    'gps': (31.83273947023218, 35.1801628605877),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Bozkath',
#    'modern name': '',
#    'gps': (31.56485056116292, 34.8467256730566),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Telem',
#    'modern name': '',
#    'gps': (32.049953, 35.733402),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Iphtah',
#    'modern name': '',
#    'gps': (31.8099, 34.9365),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Ithnan',
#    'modern name': '',
#    'gps': (32.049953, 35.733402),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Jokdeam',
#    'modern name': '',
#    'gps': (31.366667, 35.0),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Elim',
#    'modern name': '',
#    'gps': (29.306194, 32.980924),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Cush',
#    'modern name': '',
#    'gps': (21.959788, 31.343557),
#    'uncertain': '',
#    'comment': '>'},
#   {'name': 'Anab',
#    'modern name': '',
#    'gps': (31.403888, 34.944185),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Kishon',
#    'modern name': '',
#    'gps': (32.761948, 35.064096),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Thebez',
#    'modern name': '',
#    'gps': (32.3241024517848, 35.36825275634464),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Mahanaim',
#    'modern name': '',
#    'gps': (32.214708, 35.632914),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Pirathon',
#    'modern name': '',
#    'gps': (32.286022, 35.022944),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Media',
#    'modern name': '',
#    'gps': (34.798311, 48.514966),
#    'uncertain': '',
#    'comment': '>'},
#   {'name': 'Neballat',
#    'modern name': '',
#    'gps': (31.992079, 34.957563),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Gilboa',
#    'modern name': '',
#    'gps': (32.516667, 35.4),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Ecbatana',
#    'modern name': '',
#    'gps': (34.798311, 48.514966),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Damascus',
#    'modern name': '',
#    'gps': (33.519299, 36.31344999999999),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Zoan',
#    'modern name': '',
#    'gps': (30.97461982407924, 31.88417306768534),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Bethuel',
#    'modern name': '',
#    'gps': (32.049953, 35.733402),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Bashan',
#    'modern name': '',
#    'gps': (32.80007552505443, 35.93730130476259),
#    'uncertain': '',
#    'comment': '>'},
#   {'name': 'Babel',
#    'modern name': '',
#    'gps': (32.53650368616845, 44.42088287373876),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Gederothaim',
#    'modern name': '',
#    'gps': (31.823337, 34.777779),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Sitnah',
#    'modern name': '',
#    'gps': (31.39129109635703, 34.56057015639144),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Rakkon',
#    'modern name': '',
#    'gps': (32.132898, 34.788144),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Dannah',
#    'modern name': '',
#    'gps': (31.561025, 34.975472),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Eltekon',
#    'modern name': '',
#    'gps': (31.66057, 34.995406),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Luhith',
#    'modern name': '',
#    'gps': (31.288056, 35.515),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Arab',
#    'modern name': '',
#    'gps': (31.450746, 35.045648),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Arubboth',
#    'modern name': '',
#    'gps': (31.68123465358001, 34.97639817516712),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Ahava',
#    'modern name': '',
#    'gps': (33.625197, 42.786647),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Adamah',
#    'modern name': '',
#    'gps': (32.7253, 35.4382),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Kedemoth',
#    'modern name': '',
#    'gps': (31.646073, 35.894537),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Shebarim',
#    'modern name': '',
#    'gps': (31.91697811712517, 35.26122639380886),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Amad',
#    'modern name': '',
#    'gps': (33.019337, 35.173644),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Shual',
#    'modern name': '',
#    'gps': (31.95378955858199, 35.29913577541004),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Anaharath',
#    'modern name': '',
#    'gps': (32.607039, 35.397389),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Nibshan',
#    'modern name': '',
#    'gps': (31.46152536164766, 35.39241108242345),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Gozan',
#    'modern name': '',
#    'gps': (36.840013, 40.06889),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Helbon',
#    'modern name': '',
#    'gps': (33.664912, 36.248576),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Manahath',
#    'modern name': '',
#    'gps': (31.752603, 35.181972),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Sela',
#    'modern name': '',
#    'gps': (30.32243571223214, 35.45627946919968),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Sin',
#    'modern name': '',
#    'gps': (28.838778, 33.420573),
#    'uncertain': '',
#    'comment': '>'},
#   {'name': 'Ophni',
#    'modern name': '',
#    'gps': (31.961989, 35.215483),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Cozeba',
#    'modern name': '',
#    'gps': (31.7, 35.0),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Mashal',
#    'modern name': '',
#    'gps': (33.047808, 35.146201),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Oboth',
#    'modern name': '',
#    'gps': (31.49684513710609, 35.78284105296996),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Rogelim',
#    'modern name': '',
#    'gps': (32.214708, 35.632914),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Rimmono',
#    'modern name': '',
#    'gps': (32.781808, 35.321364),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Silla',
#    'modern name': '',
#    'gps': (31.777444, 35.234935),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Bered',
#    'modern name': '',
#    'gps': (30.68771281376111, 34.49479554246946),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Daberath',
#    'modern name': '',
#    'gps': (32.69171267584284, 35.37171031061986),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Shepham',
#    'modern name': '',
#    'gps': (34.353071, 36.385705),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Zalmon',
#    'modern name': '',
#    'gps': (32.23293813761263, 35.27304180036391),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Dimnah',
#    'modern name': '',
#    'gps': (32.781808, 35.321364),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Seneh',
#    'modern name': '',
#    'gps': (31.85309428405443, 35.28616916703533),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Zephath',
#    'modern name': '',
#    'gps': (30.880918, 34.63062),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Mishal',
#    'modern name': '',
#    'gps': (33.047808, 35.146201),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Hammon',
#    'modern name': '',
#    'gps': (33.125828, 35.165),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Beon',
#    'modern name': '',
#    'gps': (31.679454, 35.734892),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Hammath',
#    'modern name': '',
#    'gps': (33.125828, 35.165),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Lakkum',
#    'modern name': '',
#    'gps': (32.68695640243183, 35.39091304299688),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Halah',
#    'modern name': '',
#    'gps': (36.344972, 40.789333),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Shittim',
#    'modern name': '',
#    'gps': (31.85826217905818, 35.64156652792805),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Remeth',
#    'modern name': '',
#    'gps': (32.5559631396043, 35.33078927843792),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Ijon',
#    'modern name': '',
#    'gps': (33.32804402945069, 35.61187505342423),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Arnon',
#    'modern name': '',
#    'gps': (31.4288, 35.677009),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Minnith',
#    'modern name': '',
#    'gps': (31.75, 35.85),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Hormah',
#    'modern name': '',
#    'gps': (30.880918, 34.63062),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Helbah',
#    'modern name': '',
#    'gps': (34.066067, 35.865801),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Hukok',
#    'modern name': '',
#    'gps': (32.955448, 35.211971),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Tolad',
#    'modern name': '',
#    'gps': (32.049953, 35.733402),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Sirah',
#    'modern name': '',
#    'gps': (31.55, 35.1),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Karnaim',
#    'modern name': '',
#    'gps': (32.7666666667, 36.0166666667),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Hadrach',
#    'modern name': '',
#    'gps': (33.519299, 36.31344999999999),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Pharpar',
#    'modern name': '',
#    'gps': (33.379601, 36.306085),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Naaran',
#    'modern name': '',
#    'gps': (31.949518, 35.45873),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Rekem',
#    'modern name': '',
#    'gps': (31.869343, 35.197712),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Euphrates',
#    'modern name': '',
#    'gps': (35.090577, 40.42778),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Netaim',
#    'modern name': '',
#    'gps': (31.823337, 34.777779),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Enaim',
#    'modern name': '',
#    'gps': (31.784368, 34.90968),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Juttah',
#    'modern name': '',
#    'gps': (31.45, 35.083333),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Argob',
#    'modern name': '',
#    'gps': (33.144, 36.136),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Horesh',
#    'modern name': '',
#    'gps': (31.45113920529978, 35.08840337232346),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Besor',
#    'modern name': '',
#    'gps': (31.398056, 34.436667),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Kartah',
#    'modern name': '',
#    'gps': (32.753141, 35.279335),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Sephar',
#    'modern name': '',
#    'gps': (14.550219, 44.392642),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Maon',
#    'modern name': '',
#    'gps': (31.41666666666668, 35.1166666666667),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Ellasar',
#    'modern name': '',
#    'gps': (37.056944, 40.997222),
#    'uncertain': '',
#    'comment': '>'},
#   {'name': 'Shen',
#    'modern name': '',
#    'gps': (31.83273947023218, 35.1801628605877),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Gallim',
#    'modern name': '',
#    'gps': (31.816667, 35.25),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Shaalabbin',
#    'modern name': '',
#    'gps': (31.870364, 34.981728),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Arpad',
#    'modern name': '',
#    'gps': (35.136204, 36.749488),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Tabbath',
#    'modern name': '',
#    'gps': (32.35601, 35.536929),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Nephtoah',
#    'modern name': '',
#    'gps': (31.683036, 35.167987),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Pekod',
#    'modern name': '',
#    'gps': (32.53650368616845, 44.42088287373876),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Jabneh',
#    'modern name': '',
#    'gps': (31.865518, 34.746856),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Shahazumah',
#    'modern name': '',
#    'gps': (32.40643, 35.504628),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Idalah',
#    'modern name': '',
#    'gps': (32.733333, 35.166667),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Makheloth',
#    'modern name': '',
#    'gps': (30.317396, 35.407152),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Senir',
#    'modern name': '',
#    'gps': (33.41615982399708, 35.85725617635589),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Carmel',
#    'modern name': '',
#    'gps': (31.43333151674604, 35.13333188530802),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Shaphir',
#    'modern name': '',
#    'gps': (31.743719, 34.694006),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Bahurim',
#    'modern name': '',
#    'gps': (31.824736, 35.388486),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Beer',
#    'modern name': '',
#    'gps': (30.998062, 35.498547),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Moladah',
#    'modern name': '',
#    'gps': (31.162327, 35.057114),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Beeroth',
#    'modern name': '',
#    'gps': (31.90007449127097, 35.21668800602465),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Taberah',
#    'modern name': '',
#    'gps': (28.916667, 34.5),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Zaphon',
#    'modern name': '',
#    'gps': (32.23771, 35.585865),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Suphah',
#    'modern name': '',
#    'gps': (27.088473, 34.771729),
#    'uncertain': '',
#    'comment': '>'},
#   {'name': 'Horeb',
#    'modern name': '',
#    'gps': (28.539722, 33.973333),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Telassar',
#    'modern name': '',
#    'gps': (32.18919123705116, 48.25788647687722),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Hepher',
#    'modern name': '',
#    'gps': (32.3667, 34.8833),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Teman',
#    'modern name': '',
#    'gps': (30.203813, 35.732568),
#    'uncertain': '',
#    'comment': '>'},
#   {'name': 'Gittaim',
#    'modern name': '',
#    'gps': (31.963575, 34.952536),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Medeba',
#    'modern name': '',
#    'gps': (31.72045763248588, 35.79197231962891),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Haradah',
#    'modern name': '',
#    'gps': (30.317396, 35.407152),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Jagur',
#    'modern name': '',
#    'gps': (31.1858, 34.96745),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Jotbah',
#    'modern name': '',
#    'gps': (29.75804307645581, 35.0306017443078),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Merom',
#    'modern name': '',
#    'gps': (33.075269, 35.60548),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Heshmon',
#    'modern name': '',
#    'gps': (31.215418, 34.942986),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Zoar',
#    'modern name': '',
#    'gps': (30.9265225301655, 35.4190606947832),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Tahpanhes',
#    'modern name': '',
#    'gps': (30.860556, 32.171389),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Zelzah',
#    'modern name': '',
#    'gps': (31.717666, 35.187019),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Ulai',
#    'modern name': '',
#    'gps': (32.178696, 48.22489),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Gezer',
#    'modern name': '',
#    'gps': (31.87611111111111, 34.9225),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Gath',
#    'modern name': '',
#    'gps': (31.69352950368834, 34.84388288576839),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Rephidim',
#    'modern name': '',
#    'gps': (28.73106102564323, 33.84169995726504),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Jabez',
#    'modern name': '',
#    'gps': (31.70536129174666, 35.21026630105202),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Philistia',
#    'modern name': '',
#    'gps': (33.56316734135746, 35.36634649354799),
#    'uncertain': '',
#    'comment': '>'},
#   {'name': 'Punon',
#    'modern name': '',
#    'gps': (31.49684513710609, 35.78284105296996),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Aphekah',
#    'modern name': '',
#    'gps': (32.1047126614992, 34.93197921211777),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Lod',
#    'modern name': '',
#    'gps': (31.95138888888889, 34.89527777777778),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Cun',
#    'modern name': '',
#    'gps': (33.93148, 36.152049),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Nimrim',
#    'modern name': '',
#    'gps': (31.133191, 35.531138),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Tophel',
#    'modern name': '',
#    'gps': (30.936991, 35.61687),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Kerioth',
#    'modern name': '',
#    'gps': (31.58333333329998, 35.70000000000012),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Rabbith',
#    'modern name': '',
#    'gps': (32.391416, 35.377302),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Dinhabah',
#    'modern name': '',
#    'gps': (30.336614, 35.529889),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Abel-beth-maacah',
#    'modern name': '',
#    'gps': (33.26852614315892, 35.57804682248786),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Dimonah',
#    'modern name': '',
#    'gps': (31.1858, 34.96745),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Laban',
#    'modern name': '',
#    'gps': (31.8099, 34.9365),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Recah',
#    'modern name': '',
#    'gps': (31.70536129174666, 35.21026630105202),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Arad',
#    'modern name': '',
#    'gps': (31.28098170907087, 35.12636584365214),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Dizahab',
#    'modern name': '',
#    'gps': (28.507836, 34.516339),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Dabbesheth',
#    'modern name': '',
#    'gps': (33.0, 35.266682),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Shilhim',
#    'modern name': '',
#    'gps': (31.282222, 34.4825),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Arvad',
#    'modern name': '',
#    'gps': (34.856082, 35.858485),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Sodom',
#    'modern name': '',
#    'gps': (31.19656033132318, 35.39648411813492),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Anim',
#    'modern name': '',
#    'gps': (31.373521, 35.074552),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Machpelah',
#    'modern name': '',
#    'gps': (31.52464794555393, 35.11073465087356),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Salecah',
#    'modern name': '',
#    'gps': (32.493941, 36.710337),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Helam',
#    'modern name': '',
#    'gps': (32.1843727808126, 35.70287002746794),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Horonaim',
#    'modern name': '',
#    'gps': (31.288056, 35.515),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Pithom',
#    'modern name': '',
#    'gps': (30.59385132817632, 32.18555803140015),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Hashmonah',
#    'modern name': '',
#    'gps': (30.317396, 35.407152),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Nezib',
#    'modern name': '',
#    'gps': (31.58805, 34.992389),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Acco',
#    'modern name': '',
#    'gps': (32.927583, 35.081555),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Peniel',
#    'modern name': '',
#    'gps': (32.1843727808126, 35.70287002746794),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Arabia',
#    'modern name': '',
#    'gps': (27.4, 37.7),
#    'uncertain': '',
#    'comment': '>'},
#   {'name': 'Eshtemoa',
#    'modern name': '',
#    'gps': (31.373521, 35.074552),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Avith',
#    'modern name': '',
#    'gps': (30.734691, 35.60625),
#    'uncertain': '?',
#    'comment': '>'},
#   {'name': 'Telaim',
#    'modern name': '',
#    'gps': (32.049953, 35.733402),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Kattath',
#    'modern name': '',
#    'gps': (32.753141, 35.279335),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Eshan',
#    'modern name': '',
#    'gps': (31.420175, 35.033537),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Shiloh',
#    'modern name': '',
#    'gps': (32.05570050712985, 35.28952869712683),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Shaalbim',
#    'modern name': '',
#    'gps': (31.870364, 34.981728),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Berothah',
#    'modern name': '',
#    'gps': (33.93148, 36.152049),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Zarephath',
#    'modern name': '',
#    'gps': (33.4333, 35.3),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Kamon',
#    'modern name': '',
#    'gps': (32.042523, 35.724241),
#    'uncertain': '',
#    'comment': '<>'},
#   {'name': 'Alemeth',
#    'modern name': '',
#    'gps': (31.828406, 35.287637),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Rabbah',
#    'modern name': '',
#    'gps': (31.95018855468469, 35.92413135872749),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Abel',
#    'modern name': '',
#    'gps': (33.26852614315892, 35.57804682248786),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Tirzah',
#    'modern name': '',
#    'gps': (32.27136869937776, 35.29430386845415),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Cabbon',
#    'modern name': '',
#    'gps': (31.5, 34.7667),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Hobah',
#    'modern name': '',
#    'gps': (33.5, 36.466667),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Alush',
#    'modern name': '',
#    'gps': (28.770015, 33.40046),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Adam',
#    'modern name': '',
#    'gps': (32.09772014797369, 35.56469085401976),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Dedan',
#    'modern name': '',
#    'gps': (26.625139, 37.919663),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Racal',
#    'modern name': '',
#    'gps': (31.43333151674604, 35.13333188530802),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Rameses',
#    'modern name': '',
#    'gps': (30.799370210096, 31.834216685474),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Kabzeel',
#    'modern name': '',
#    'gps': (31.1858, 34.96745),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Mesha',
#    'modern name': '',
#    'gps': (28.85726, 34.859127),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Pau',
#    'modern name': '',
#    'gps': (30.734691, 35.60625),
#    'uncertain': '',
#    'comment': '<>'},
#   {'name': 'Parah',
#    'modern name': '',
#    'gps': (31.833333, 35.3),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Giah',
#    'modern name': '',
#    'gps': (31.869005, 35.343177),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Ummah',
#    'modern name': '',
#    'gps': (33.104377, 35.180623),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Gomorrah',
#    'modern name': '',
#    'gps': (31.15724866533878, 35.4739543300078),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Migdol',
#    'modern name': '',
#    'gps': (30.020296, 32.372233),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Pisgah',
#    'modern name': '',
#    'gps': (31.76503129703305, 35.71856575741812),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Zalmonah',
#    'modern name': '',
#    'gps': (31.49684513710609, 35.78284105296996),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Hermon',
#    'modern name': '',
#    'gps': (33.41615982399708, 35.85725617635589),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Edom',
#    'modern name': '',
#    'gps': (30.734691, 35.60625),
#    'uncertain': '',
#    'comment': '>'},
#   {'name': 'Zarethan',
#    'modern name': '',
#    'gps': (32.267821, 35.576613),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Gibbethon',
#    'modern name': '',
#    'gps': (31.976623, 35.004896),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Etham',
#    'modern name': '',
#    'gps': (30.467511, 32.282767),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Zenan',
#    'modern name': '',
#    'gps': (31.743719, 34.694006),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Lasha',
#    'modern name': '',
#    'gps': (31.718148, 35.584826),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Kain',
#    'modern name': '',
#    'gps': (31.5, 35.166667),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Jokneam',
#    'modern name': '',
#    'gps': (32.66454576550823, 35.10891818863304),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Jazer',
#    'modern name': '',
#    'gps': (31.94352951689796, 35.72776961157128),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Peor',
#    'modern name': '',
#    'gps': (31.76503129703305, 35.71856575741812),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Caphtor',
#    'modern name': '',
#    'gps': (35.171239, 25.007204),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'City of Salt',
#    'modern name': '',
#    'gps': (31.46152536164766, 35.39241108242345),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Asshur',
#    'modern name': '',
#    'gps': (36.35941, 43.152887),
#    'uncertain': '',
#    'comment': '>'},
#   {'name': 'Adullam',
#    'modern name': '',
#    'gps': (31.65, 35.0),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Waheb',
#    'modern name': '',
#    'gps': (27.088473, 34.771729),
#    'uncertain': '?',
#    'comment': '>'},
#   {'name': 'Kartan',
#    'modern name': '',
#    'gps': (33.125828, 35.165),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Moseroth',
#    'modern name': '',
#    'gps': (30.317396, 35.407152),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Adithaim',
#    'modern name': '',
#    'gps': (31.7001, 34.89532),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Amana',
#    'modern name': '',
#    'gps': (33.68137, 36.055039),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Shur',
#    'modern name': '',
#    'gps': (30.2354, 33.247),
#    'uncertain': '',
#    'comment': '>'},
#   {'name': 'Meconah',
#    'modern name': '',
#    'gps': (31.370835, 34.860665),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Hena',
#    'modern name': '',
#    'gps': (34.467725, 41.964955),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Madmenah',
#    'modern name': '',
#    'gps': (31.8, 35.25),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Kenath',
#    'modern name': '',
#    'gps': (32.756919, 36.6164),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Hebron',
#    'modern name': '',
#    'gps': (31.53577362133176, 35.09409986578734),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Shikkeron',
#    'modern name': '',
#    'gps': (31.77761410537458, 34.85214575880509),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Aner',
#    'modern name': '',
#    'gps': (32.51723975501718, 35.21632508826309),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Jahzah',
#    'modern name': '',
#    'gps': (31.50100308502659, 35.92063125199366),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Ashan',
#    'modern name': '',
#    'gps': (31.8099, 34.9365),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Nineveh',
#    'modern name': '',
#    'gps': (36.35941, 43.152887),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Pai',
#    'modern name': '',
#    'gps': (30.734691, 35.60625),
#    'uncertain': '',
#    'comment': '<>'},
#   {'name': 'Secu',
#    'modern name': '',
#    'gps': (31.883333, 35.2),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Libya',
#    'modern name': '',
#    'gps': (32.824979, 21.858301),
#    'uncertain': '',
#    'comment': '>'},
#   {'name': 'Ether',
#    'modern name': '',
#    'gps': (31.8099, 34.9365),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Gibeon',
#    'modern name': '',
#    'gps': (31.84684772753698, 35.18491237777512),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Azmon',
#    'modern name': '',
#    'gps': (30.958506, 34.3805),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Hamonah',
#    'modern name': '',
#    'gps': (31.49684513710609, 35.78284105296996),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Mesopotamia',
#    'modern name': '',
#    'gps': (32.53650368616845, 44.42088287373876),
#    'uncertain': '',
#    'comment': '>'},
#   {'name': 'Ziphron',
#    'modern name': '',
#    'gps': (34.229499, 37.240077),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Egypt',
#    'modern name': '',
#    'gps': (30.108086, 31.33822),
#    'uncertain': '',
#    'comment': '>'},
#   {'name': 'Lehi',
#    'modern name': '',
#    'gps': (31.75274835811488, 34.97660913147738),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Joppa',
#    'modern name': '',
#    'gps': (32.05351968494696, 34.75042606009946),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Enam',
#    'modern name': '',
#    'gps': (32.15, 35.126),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Masrekah',
#    'modern name': '',
#    'gps': (30.734691, 35.60625),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Jahaz',
#    'modern name': '',
#    'gps': (31.50100308502659, 35.92063125199366),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Buz',
#    'modern name': '',
#    'gps': (26.625139, 37.919663),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Jeshua',
#    'modern name': '',
#    'gps': (31.162327, 35.057114),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Ziddim',
#    'modern name': '',
#    'gps': (32.814279, 35.435872),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Neiel',
#    'modern name': '',
#    'gps': (32.894254, 35.221877),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Iyim',
#    'modern name': '',
#    'gps': (31.49684513710609, 35.78284105296996),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Adadah',
#    'modern name': '',
#    'gps': (31.1858, 34.96745),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Minni',
#    'modern name': '',
#    'gps': (40.6, 44.6),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Galeed',
#    'modern name': '',
#    'gps': (32.56526757366849, 36.00555930879645),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Dophkah',
#    'modern name': '',
#    'gps': (28.770015, 33.40046),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Zobah',
#    'modern name': '',
#    'gps': (34.312571, 36.925484),
#    'uncertain': '',
#    'comment': '>'},
#   {'name': 'Ephah',
#    'modern name': '',
#    'gps': (28.932881, 34.90832),
#    'uncertain': '?',
#    'comment': '>'},
#   {'name': 'Hereth',
#    'modern name': '',
#    'gps': (31.621492, 35.029273),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Uz',
#    'modern name': '',
#    'gps': (30.0334, 36.44839),
#    'uncertain': '',
#    'comment': '>'},
#   {'name': 'Kehelathah',
#    'modern name': '',
#    'gps': (30.317396, 35.407152),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Suph',
#    'modern name': '',
#    'gps': (27.088473, 34.771729),
#    'uncertain': '',
#    'comment': '>'},
#   {'name': 'Tob',
#    'modern name': '',
#    'gps': (32.561735, 36.240494),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Massah',
#    'modern name': '',
#    'gps': (28.73106102564323, 33.84169995726504),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Hadid',
#    'modern name': '',
#    'gps': (31.963575, 34.952536),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Biziothiah',
#    'modern name': '',
#    'gps': (31.24495217357714, 34.8408885849849),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Ziz',
#    'modern name': '',
#    'gps': (31.572903, 35.406346),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Erech',
#    'modern name': '',
#    'gps': (32.322222, 45.636111),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Hanes',
#    'modern name': '',
#    'gps': (29.085425, 30.934402),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Jabesh',
#    'modern name': '',
#    'gps': (32.37982175236296, 35.61158746493092),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Harmon',
#    'modern name': '',
#    'gps': (32.28023100000001, 35.19792900000002),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Makkedah',
#    'modern name': '',
#    'gps': (31.935117, 34.781326),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Elath',
#    'modern name': '',
#    'gps': (29.528502, 35.005732),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Ibleam',
#    'modern name': '',
#    'gps': (32.45, 35.2833),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Moserah',
#    'modern name': '',
#    'gps': (30.317396, 35.407152),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Neah',
#    'modern name': '',
#    'gps': (32.894254, 35.221877),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Nob',
#    'modern name': '',
#    'gps': (31.799605, 35.23298),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Gimzo',
#    'modern name': '',
#    'gps': (31.928659, 34.943219),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Kitron',
#    'modern name': '',
#    'gps': (32.753141, 35.279335),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Jabbok',
#    'modern name': '',
#    'gps': (32.193237, 35.676305),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Mareshah',
#    'modern name': '',
#    'gps': (31.60393321295081, 34.90237777777779),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Kir',
#    'modern name': '',
#    'gps': (31.18132579594509, 35.70214779044711),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Balah',
#    'modern name': '',
#    'gps': (31.24495217357714, 34.8408885849849),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Atharim',
#    'modern name': '',
#    'gps': (30.880918, 34.63062),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Shunem',
#    'modern name': '',
#    'gps': (32.60563102234625, 35.33430585716489),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Persia',
#    'modern name': '',
#    'gps': (34.798311, 48.514966),
#    'uncertain': '',
#    'comment': '>'},
#   {'name': 'Aijalon',
#    'modern name': '',
#    'gps': (31.84117376619545, 35.02537926743067),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Zererah',
#    'modern name': '',
#    'gps': (32.267821, 35.576613),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Helech',
#    'modern name': '',
#    'gps': (34.856082, 35.858485),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Allammelech',
#    'modern name': '',
#    'gps': (32.97829, 35.182915),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Anem',
#    'modern name': '',
#    'gps': (32.46349905885267, 35.3036831926058),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Sharuhen',
#    'modern name': '',
#    'gps': (31.282222, 34.4825),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Leshem',
#    'modern name': '',
#    'gps': (33.24865997897308, 35.65248345039043),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Laishah',
#    'modern name': '',
#    'gps': (31.8, 35.25),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Aiath',
#    'modern name': '',
#    'gps': (31.91697811712517, 35.26122639380886),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Tarshish',
#    'modern name': '',
#    'gps': (36.95299512880268, -6.379340234132555),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Elishah',
#    'modern name': '',
#    'gps': (35.018306, 33.207693),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Esek',
#    'modern name': '',
#    'gps': (31.39129109635703, 34.56057015639144),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Migron',
#    'modern name': '',
#    'gps': (31.82378102460309, 35.23100936128631),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Eltolad',
#    'modern name': '',
#    'gps': (32.049953, 35.733402),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Mearah',
#    'modern name': '',
#    'gps': (33.633333, 35.433333),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Gob',
#    'modern name': '',
#    'gps': (31.87611111111111, 34.9225),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Calno',
#    'modern name': '',
#    'gps': (32.127213, 45.229995),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Middin',
#    'modern name': '',
#    'gps': (31.743894, 35.401591),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Bozez',
#    'modern name': '',
#    'gps': (31.85716450320853, 35.28714718824809),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Jattir',
#    'modern name': '',
#    'gps': (31.40143851886152, 35.06941349210527),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Golan',
#    'modern name': '',
#    'gps': (32.80007552505443, 35.93730130476259),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Nimrah',
#    'modern name': '',
#    'gps': (31.900811, 35.625693),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Shaalim',
#    'modern name': '',
#    'gps': (31.84684772753698, 35.18491237777512),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Ezem',
#    'modern name': '',
#    'gps': (32.049953, 35.733402),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Bealoth',
#    'modern name': '',
#    'gps': (32.049953, 35.733402),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Ararat',
#    'modern name': '',
#    'gps': (39.70289295384448, 44.29818047261773),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Ono',
#    'modern name': '',
#    'gps': (32.02222222222223, 34.86666666666667),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Horem',
#    'modern name': '',
#    'gps': (33.166667, 35.433333),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Jeshimon',
#    'modern name': '',
#    'gps': (31.46152536164766, 35.39241108242345),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Sebam',
#    'modern name': '',
#    'gps': (31.815283, 35.766738),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Tibhath',
#    'modern name': '',
#    'gps': (33.93148, 36.152049),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Babylon',
#    'modern name': '',
#    'gps': (32.53650368616845, 44.42088287373876),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Ophel',
#    'modern name': '',
#    'gps': (31.777444, 35.234935),
#    'uncertain': '',
#    'comment': '<'},
#   {'name': 'Hapharaim',
#    'modern name': '',
#    'gps': (32.60868269540592, 35.28826433084549),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Shema',
#    'modern name': '',
#    'gps': (31.162327, 35.057114),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Jericho',
#    'modern name': '',
#    'gps': (31.87060143818292, 35.44386371224434),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Kidron',
#    'modern name': '',
#    'gps': (31.772134, 35.236596),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Topheth',
#    'modern name': '',
#    'gps': (31.769079, 35.227994),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Zedad',
#    'modern name': '',
#    'gps': (34.312571, 36.925484),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Ar',
#    'modern name': '',
#    'gps': (31.44980942220132, 35.59395836278803),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Gaza',
#    'modern name': '',
#    'gps': (31.52481769532773, 34.4333647185274),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Zeboiim',
#    'modern name': '',
#    'gps': (31.11942270162137, 35.41253049195169),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Mephaath',
#    'modern name': '',
#    'gps': (31.85, 35.933333),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Shinar',
#    'modern name': '',
#    'gps': (32.53650368616845, 44.42088287373876),
#    'uncertain': '',
#    'comment': '>'},
#   {'name': 'Hamath',
#    'modern name': '',
#    'gps': (35.136204, 36.749488),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Zaanannim',
#    'modern name': '',
#    'gps': (33.11298357486105, 35.53361334150225),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Hezron',
#    'modern name': '',
#    'gps': (33.01718199667929, 35.56804856758258),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Eshtaol',
#    'modern name': '',
#    'gps': (31.782429, 35.009012),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Gilead',
#    'modern name': '',
#    'gps': (32.042523, 35.724241),
#    'uncertain': '',
#    'comment': '>'},
#   {'name': 'Calneh',
#    'modern name': '',
#    'gps': (32.127213, 45.229995),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Maroth',
#    'modern name': '',
#    'gps': (31.743719, 34.694006),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Ashdod',
#    'modern name': '',
#    'gps': (31.80299971086164, 34.6351145939134),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Ithlah',
#    'modern name': '',
#    'gps': (31.823593, 35.075769),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Secacah',
#    'modern name': '',
#    'gps': (31.766667, 35.283333),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Hukkok',
#    'modern name': '',
#    'gps': (32.882153, 35.496694),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Sur',
#    'modern name': '',
#    'gps': (31.777444, 35.234935),
#    'uncertain': '',
#    'comment': '<'},
#   {'name': 'Habor',
#    'modern name': '',
#    'gps': (36.344972, 40.789333),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Japhia',
#    'modern name': '',
#    'gps': (32.691633, 35.274955),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Kue',
#    'modern name': '',
#    'gps': (36.91802695356275, 34.89153398422567),
#    'uncertain': '',
#    'comment': '>'},
#   {'name': 'Geder',
#    'modern name': '',
#    'gps': (31.63333, 35.083333),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Makaz',
#    'modern name': '',
#    'gps': (31.870364, 34.981728),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Galilee',
#    'modern name': '',
#    'gps': (32.70674542474383, 35.30152807767973),
#    'uncertain': '',
#    'comment': '>'},
#   {'name': 'Hazeroth',
#    'modern name': '',
#    'gps': (28.916667, 34.5),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Shibah',
#    'modern name': '',
#    'gps': (31.24495217357714, 34.8408885849849),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Zior',
#    'modern name': '',
#    'gps': (31.589719, 35.148296),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Megiddo',
#    'modern name': '',
#    'gps': (32.58418313614938, 35.18229165870594),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Zered',
#    'modern name': '',
#    'gps': (30.884128, 35.897633),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Samaria',
#    'modern name': '',
#    'gps': (32.28023100000001, 35.19792900000002),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Elon',
#    'modern name': '',
#    'gps': (31.973818, 35.116531),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Ebez',
#    'modern name': '',
#    'gps': (32.261621, 35.328129),
#    'uncertain': '',
#    'comment': ''},
#   {'name': 'Jotbathah',
#    'modern name': '',
#    'gps': (29.75804307645581, 35.0306017443078),
#    'uncertain': '?',
#    'comment': ''},
#   {'name': 'Tema',
#    'modern name': '',
#    'gps': (27.633172, 38.554125),
#    'uncertain': '',
#    'comment': ''}]}

# %% [markdown]
# Exporting longitude feature:

# %%
nodeFeatures = dict(long=long_dict)
metaData = dict(
    long=dict(
        valueType='str',
        description='Longitude of topological lexemes. The geocoding is retrieved from the data set available at https://www.openbible.info/geo/data/merged.txt',
        coreData='BHSA',
        coreVersion=VERSION
    )
)
TF = Fabric(locations=thisTempTf, silent=True)
TF.save(nodeFeatures=nodeFeatures, edgeFeatures={}, metaData=metaData)

# %% [markdown]
# #### Retrieving the word nodes for all lexemes annotated for topes in the ETCBC database:

# %%
def getRefFromGloss():
    ref_dict = collections.defaultdict(str)

    for n in F.otype.s('word'):
        lex = L.u(n, 'lex')[0]
        if F.nametype.v(lex) == 'topo':
            gloss = F.gloss.v(lex)
            ref_dict[gloss] += f' {str(n)}'
    return ref_dict

# %%
ref_dict = getRefFromGloss()

# %%
#ref_dict

# %% [markdown]
# ## Visualizations

# %%
def marker_locations(lst):
    return [topo['gps'] for topo in lst]

def marker_info_box(lst):
    global ref_dict
    try:
        ref_dict
    except:
        ref_dict = getRefFromGloss()

    link_dict = {}
    for gloss in ref_dict:
        ref_list = ref_dict[gloss].split()
        ShbLink = 'http://shebanq.ancient-data.org/hebrew/text?'
        link_string = ''
        for r in ref_list:
            bo, ch, ve = T.sectionFromNode(int(r))
            link = f'<a href="{ShbLink}book={bo}&chapter={ch}&verse={ve}">{bo[:3]} {ch}:{ve}</a> '
            link_string += link
        link_dict[gloss] = link_string
    
    place_ref_list = []
    for pl in lst:
        dic = {}
        dic['name'] = pl['name']
        dic['link'] = link_dict[pl['name']]
        place_ref_list.append(dic)

    info_box_template = '''
    <dl>
    <dt>{name}</dt>
    <dd>{link}</dd>
    </dl>
    '''
    info_box = [info_box_template.format(name=gl['name'], link=gl['link']) for gl in place_ref_list]
    return info_box

# marker_info_box(geo_coding)

# %%
def geo_coding_places(lst):
    '''
    input: list of dictionaries
    output: list of names in list of dictionaries
    '''
    name_lst = []
    
    for l in lst:
        name_lst.append(l['name'])
        
    return name_lst

def createMap(place):
    '''
    The function creates a sublist of the list of dictionaries. Each element of the sublist
    corresponds to the place names in question.
    '''
    
    sub_lst = []
    
    for pl in place:
        if pl in geo_coding_places(geo_coding):
            for l in geo_coding:
                if l['name'] == pl:
                    sub_lst.append(l)
        else:
            print(f'{pl} does not exist in the dictionary')
            
    symbols = gmaps.symbol_layer(marker_locations(sub_lst), info_box_content=marker_info_box(sub_lst),
                                 fill_color='red', stroke_color='red', scale=3)
    
    m = gmaps.figure(map_type='TERRAIN')
    m.add_layer(symbols)
    return m

def all():
    '''
    Feeds a list of all glosses with gps-coordinates into the function createMap()
    '''
    
    lst = geo_coding_places(geo_coding)
    return geocodingPlace(lst)

# %%
place = ['Sinai','Jerusalem','Tarshish']

createMap(place)
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
all()
# Out:
# Figure(layout=FigureLayout(height='420px'))
